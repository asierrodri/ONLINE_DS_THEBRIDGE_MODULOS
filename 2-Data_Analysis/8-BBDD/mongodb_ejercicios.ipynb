# %%
import pandas as pd

# %%
restaurantes = pd.read_csv("data.restaurants.csv")

# %%
restaurantes.head()
# Out:
#                         _id address.building  address.coord[0]  \
# 0  692d7a81e05a308f84eae95b             1007        -73.856077
# 1  692d7a81e05a308f84eae95c              469        -73.961704
# 2  692d7a81e05a308f84eae95d              351        -73.985136
# 3  692d7a81e05a308f84eae95e             2780        -73.982420
# 4  692d7a81e05a308f84eae95f            97-22        -73.860115
#
#    address.coord[1]    address.street  address.zipcode    borough  \
# 0         40.848447   Morris Park Ave            10462      Bronx
# 1         40.662942   Flatbush Avenue            11225   Brooklyn
# 2         40.767692  West   57 Street            10019  Manhattan
# 3         40.579505  Stillwell Avenue            11224   Brooklyn
# 4         40.731174           63 Road            11374     Queens
#
#          cuisine            grades[0].date            grades[1].date  ...  \
# 0         Bakery  2014-03-03T00:00:00.000Z  2013-09-11T00:00:00.000Z  ...
# ...
