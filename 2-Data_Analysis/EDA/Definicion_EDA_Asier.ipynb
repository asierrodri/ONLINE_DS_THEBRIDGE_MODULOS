# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# Análisis Exploratorio del Rendimiento en Running: Influencia de Hábitos, Sueño y Carga de Entrenamiento

# %% [markdown]
# ### TEMA

# %% [markdown]
# Evaluación de cómo distintos factores personales (cadencia, sueño, consumo de tabaco, carga, fuerza, natación y momento del día) influyen en mi rendimiento como corredor, utilizando datos reales registrados por Garmin.

# %% [markdown]
# ### HIPÓTESIS 1

# %% [markdown]
# **Existe un rango de cadencia que maximiza la eficiencia corriendo. En ese rango se logran mejores ritmos sin un aumento proporcional de la frecuencia cardiaca.**

# %% [markdown]
# La cadencia se define como el numero de veces que cada pie entra en contacto con el suelo por minuto a lo largo de una actividad de carreara. Se mide en pasos por minuto (ppm). Por lo general, los corredores mas experimentados suelen tener una cadencia mayor.
#
# Uno de los objetivos de cadencia que se menciona con mas frecuencia en carreras es 180 ppm. Los corredores mas altos suelen presentar una cadencia algo mas baja.

# %% [markdown]
# ### MÁS HIPOTESIS

# %% [markdown]
# hipotesis_2 = El rendimiento es mejor cuando corro por la mañana que cuando corro por la tarde o por la noche, reflejado en la eficiencia.
#
# hipotesis_3 = Semanas con más km correlacionan con mejor eficiencia la siguiente semana.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd

# %%
asier_running = pd.read_csv("../../data/actividades_running/asier_running.csv")
ari_running = pd.read_csv("../../data/actividades_running/ari_running.csv")
ganix_running = pd.read_csv("../../data/actividades_running/ganix_running.csv")
garmin_running = pd.read_csv("../../data/actividades_running/garmin_running.csv")
log_running = pd.read_csv("../../data/actividades_running/log_running.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 asier_running = pd.read_csv("../../data/actividades_running/asier_running.csv")
#       2 ari_running = pd.read_csv("../../data/actividades_running/ari_running.csv")
#       3 ganix_running = pd.read_csv("../../data/actividades_running/ganix_running.csv")
#
# File c:\Users\Asier\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Asier\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Asier\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Asier\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Asier\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/actividades_running/asier_running.csv'
