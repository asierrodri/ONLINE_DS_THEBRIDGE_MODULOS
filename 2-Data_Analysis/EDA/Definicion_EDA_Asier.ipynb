# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# Análisis Exploratorio del Rendimiento en Running: Influencia de Hábitos, Sueño y Carga de Entrenamiento

# %% [markdown]
# ### TEMA

# %% [markdown]
# Evaluación de cómo distintos factores personales (cadencia, sueño, consumo de tabaco, carga, fuerza, natación y momento del día) influyen en mi rendimiento como corredor, utilizando datos reales registrados por Garmin.

# %% [markdown]
# ### HIPÓTESIS 1

# %% [markdown]
# Existe un rango de cadencia que maximiza la eficiencia corriendo. En ese rango se logran mejores ritmos sin un aumento proporcional de la frecuencia cardiaca.

# %% [markdown]
# La cadencia se define como el numero de veces que cada pie entra en contacto con el suelo por minuto a lo largo de una actividad de carreara. Se mide en pasos por minuto (ppm). Por lo general, los corredores mas experimentados suelen tener una cadencia mayor.
#
# Uno de los objetivos de cadencia que se menciona con mas frecuencia en carreras es 180 ppm. Los niveles de cadencia mas altos se asocian a niveles de **oscilacion vertical** mas bajos y a tiempos menores de contacto con el suelo. Los corredores mas altos suelen presentar una cadencia algo mas baja.

# %% [markdown]
# ### MÁS HIPOTESIS

# %% [markdown]
# hipotesis_2 = El rendimiento es mejor cuando corro por la mañana que cuando corro por la tarde o por la noche, reflejado en ritmos más rápidos y una menor frecuencia cardiaca.
#
# hipotesis_3 = Un aumento en la longitud media de la zancada mejora el ritmo sin necesidad de aumentar cadencia o FC.
#
# hipotesis_4 = En días con más temperatura, el ritmo empeora y la frecuencia cardíaca aumenta.
#
# hipotesis_5 = Semanas con más km correlacionan con mejor eficiencia la siguiente semana.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1.head()
# Out:
#     athlete gender         timestamp  distance (m)  elapsed time (s)  \
# 0  18042525      M  15/12/2019 09:08        2965.8               812
# 1  18042525      M  10/12/2019 19:27       10020.8              3290
# 2  18042525      M  03/12/2019 19:46       12132.2              4027
# 3  18042525      M  26/11/2019 19:46       11631.5              4442
# 4  18042525      M  19/11/2019 19:45       11708.1              4022
#
#    elevation gain (m)  average heart rate (bpm)
# 0                17.4                     150.3
# 1                52.2                     160.8
# 2               249.0                     148.9
# 3               194.0                     136.2
# 4               250.7                     146.0

# %%
# Siguiente dataset...
# df_2.head()
