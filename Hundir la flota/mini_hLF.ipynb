# %%
tablero = [[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "]]
""" 

for p in tablero:
    for i in p:
        print(i, end=" ")
    print() """
x = 0
while x < 4:
    tablero[1][x] = "B"
    x += 1
x = 3
while x < 6:
    tablero[x][3] = "B"
    x += 1
for p in tablero:
    print(p)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
i = int(input("Introduce la primera coordenada"))
j = int(input("Introduce la segunda coordenada"))

if 0 > i > 9 or j > 9:
    print("Coordenadas incorrectas")
elif tablero[i][j] == "B":
    tablero[i][j] = "x"
    print("Tocado en posición " + i + "," + j)
elif tablero[i][j] == " ":
    tablero[i][j] = "o"
    print("Agua")
else:
    print("Ya había introducido esas coordenadas")


for p in tablero:
    print(p)
# Out:
# Ya había introducido esas coordenadas
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'x', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', 'o', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'o']
