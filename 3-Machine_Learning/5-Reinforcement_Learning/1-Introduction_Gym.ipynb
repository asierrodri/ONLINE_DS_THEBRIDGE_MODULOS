# %% [markdown]
# ## Intro Aprendizaje por Refuerzo

# %% [markdown]
# Considera el escenario de enseñarle nuevos trucos a un perro. El perro no entiende nuestro lenguaje, así que no podemos decirle qué hacer. En cambio, seguimos una estrategia diferente. Emulamos una situación (o una señal), y el perro intenta responder de muchas maneras diferentes. Si la respuesta del perro es la deseada, lo recompensamos con golosinas. Ahora, adivina qué, la próxima vez que el perro se enfrenta a la misma situación, ejecuta una acción similar con aún más entusiasmo esperando más comida. Esto es como aprender "qué hacer" a partir de experiencias positivas. De manera similar, los perros tienden a aprender qué no hacer cuando se enfrentan a experiencias negativas.

# %% [markdown]
# ## Entendiendo cómo funciona el Aprendizaje por Refuerzo
#
# En un sentido más amplio, así es como funciona el Aprendizaje por Refuerzo:
#
# * Tu perro es un "agente" que está expuesto al entorno. El entorno podría ser tu casa, contigo.
# * Las situaciones que encuentran son análogas a un estado. Un ejemplo de un estado podría ser tu perro de pie y tú usando una palabra específica con cierto tono en tu sala de estar.
# * Nuestros agentes reaccionan realizando una acción para pasar de un "estado" a otro "estado"; por ejemplo, tu perro pasa de estar de pie a sentarse.
# * Después de la transición, pueden recibir una recompensa o una penalización a cambio. ¡Les das una golosina! O un "No" como penalización.
# * La política es la estrategia de elegir una acción dada un estado en espera de mejores resultados.

# %% [markdown]
# El Aprendizaje por Refuerzo se encuentra entre el espectro del Aprendizaje Supervisado y el No Supervisado, y hay algunas cosas importantes que tener en cuenta:
#
# #### No siempre es beneficioso ser codicioso
#
# **Ser codicioso no siempre funciona:**
#
# * Hay cosas que son fáciles de hacer para obtener una gratificación instantánea, y hay cosas que proporcionan recompensas a largo plazo. El objetivo no es ser codicioso buscando las recompensas inmediatas, sino optimizar las recompensas máximas durante todo el entrenamiento.
#
# #### La secuencia importa en el Aprendizaje por Refuerzo
#
# **La secuencia importa en el Aprendizaje por Refuerzo:**
#
# * La recompensa del agente no solo depende del estado actual, sino de toda la historia de estados. A diferencia del aprendizaje supervisado y no supervisado, el tiempo es importante aquí.

# %% [markdown]
# ## El proceso

# %% [markdown]
# <img src="./img/Reinforcement-Learning-Animation.gif" alt="drawing" width="650"/>

# %% [markdown]
# En cierto sentido, el Aprendizaje por Refuerzo es la ciencia de tomar decisiones óptimas utilizando experiencias. Desglosándolo, el proceso de Aprendizaje por Refuerzo involucra estos pasos simples:
#
# 1. Observación del entorno.
# 2. Decidir cómo actuar utilizando alguna estrategia.
# 3. Actuar en consecuencia.
# 4. Recibir una recompensa o penalización.
# 5. Aprender de las experiencias y refinar nuestra estrategia.
# 6. Iterar hasta encontrar una estrategia óptima.
#
# Ahora vamos a entender el Aprendizaje por Refuerzo desarrollando un agente para aprender a jugar un juego automáticamente por sí mismo.

# %% [markdown]
# ## Comenzando con Gym
#
# Gym es un conjunto de herramientas para desarrollar y comparar algoritmos de aprendizaje por refuerzo. No hace suposiciones sobre la estructura de tu agente y es compatible con cualquier biblioteca de cálculo numérico, como TensorFlow o Theano.
#
# La biblioteca Gym es una colección de problemas de prueba, o entornos, que puedes usar para desarrollar tus algoritmos de aprendizaje por refuerzo. Estos entornos tienen una interfaz compartida, lo que te permite escribir algoritmos generales.

# %%
# %pip install gymnasium[classic_control]
# %pip install pygame
# Out:
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages (from gymnasium[classic_control]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages (from gymnasium[classic_control]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages (from gymnasium[classic_control]) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[classic_control])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: pygame>=2.1.3 in /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages (from gymnasium[classic_control]) (2.6.1)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 12.5 MB/s  0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gymnasium]/2 [gymnasium]
# Successfully installed farama-notifications-0.0.4 gymnasium-1.2.3
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pygame in /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install numpy==1.23.5

# %% [markdown]
# ## Entornos
#
# Aquí tienes un ejemplo mínimo para comenzar a ejecutar algo. Esto ejecutará una instancia del entorno CartPole-v0 durante 1000 pasos de tiempo, representando el entorno en cada paso.

# %% [markdown]
#  Consiste en equilibrar un poste (péndulo) montado en la parte superior de un carrito móvil:
#  * El **objetivo** es mantener el poste en posición vertical mientras el carrito se mueve hacia adelante y hacia atrás en una pista.
#  * El **agente** (o jugador) tiene dos acciones disponibles en cada paso de tiempo: empujar el carrito hacia la izquierda o hacia la derecha.
#  * El **desafío** radica en tomar decisiones adecuadas para evitar que el poste caiga mientras se mueve el carrito.
#
#  Este problema es un ejemplo comúnmente utilizado para probar algoritmos de aprendizaje por refuerzo debido a su simplicidad y naturaleza desafiante.

# %% [markdown]
# https://gymnasium.farama.org/api/env/

# %%
import gymnasium as gym
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

# %% [markdown]
# Crea un entorno de simulación llamado MountainCar-v0.
# Este es un entorno clásico en gym en el que un coche debe moverse hacia arriba de una colina empinada.
# El objetivo es aplicar fuerza en las direcciones izquierda o derecha para ganar impulso suficiente y alcanzar la cima.

# %%
env = gym.make('MountainCar-v0')

# %% [markdown]
# Reinicia el entorno a su estado inicial.
# Esto es útil para comenzar una nueva simulación. Devuelve el estado inicial del entorno.

# %%
env.reset()
# Out:
# (array([-0.46532786,  0.        ], dtype=float32), {})

# %% [markdown]
# A continuación: se ejecuta un bucle con 300 pasos dentro del entorno.

# %% [markdown]
# ``env.render()`` dibuja el entorno en una ventana gráfica para que puedas visualizar lo que está sucediendo (por ejemplo, el carro moviéndose).

# %% [markdown]
# ``env.action_space.sample()``
# Toma una acción aleatoria en el espacio de acciones del entorno. En este caso, las acciones posibles son:
#
# * 0: Aplicar fuerza hacia la izquierda.
# * 1: No aplicar fuerza.
# * 2: Aplicar fuerza hacia la derecha.

# %%
#for i in range(300):
#    env.render()
#    time.sleep(0.1)
#    env.step(env.action_space.sample()) # take a random action
#env.close()

# %%
#numpy.__version__

# %%
import gymnasium as gym
import warnings
import numpy

warnings.filterwarnings("ignore")

# Crear el entorno
env = gym.make('MountainCar-v0')
env.reset()

# Loop para ejecutar pasos en el entorno
for i in range(300):
    env.render()  # Renderizar el entorno
    env.step(env.action_space.sample())  # Tomar una acción aleatoria

env.close()

# %%
#numpy.__version__

# %% [markdown]
# Normalmente, terminaremos la simulación antes de que el carrito-péndulo tenga permitido salir de la pantalla. Más sobre eso después. Por ahora, por favor ignora la advertencia sobre llamar a `step()` aunque este entorno ya haya devuelto `done = True`.
#
# Si deseas ver otros entornos en acción, intenta reemplazar `CartPole-v0` arriba con algo como `MountainCar-v0`, `MsPacman-v0` (requiere la dependencia de Atari), o `Hopper-v1` (requiere las dependencias de MuJoCo). Todos los entornos descienden de la clase base `Env`.
#
# Ten en cuenta que si te faltan dependencias, deberías recibir un mensaje de error útil que te diga qué te falta. (Avísanos si alguna dependencia te causa problemas sin una instrucción clara para solucionarlo). Instalar una dependencia faltante generalmente es bastante simple. También necesitarás una licencia de MuJoCo para `Hopper-v1`.

# %% [markdown]
# ## Observaciones
#
# Si queremos hacer algo mejor que tomar acciones aleatorias en cada paso, probablemente sería bueno saber realmente qué están haciendo nuestras acciones en el entorno.
#
# La función `step` del entorno devuelve exactamente lo que necesitamos. De hecho, `step` devuelve cuatro valores. Estos son:
#
# * `observation` (object): un objeto específico del entorno que representa tu observación del entorno. Por ejemplo, datos de píxeles de una cámara, ángulos de articulación y velocidades de articulación de un robot, o el estado del tablero en un juego de mesa.
# * `reward` (float): cantidad de recompensa lograda por la acción anterior. La escala varía entre entornos, pero el objetivo es siempre aumentar tu recompensa total.
# * `done` (bool): si es hora de restablecer el entorno nuevamente. La mayoría (pero no todos) de las tareas están divididas en episodios bien definidos, y `done` siendo True indica que el episodio ha terminado. (Por ejemplo, tal vez el poste se inclinó demasiado, o perdiste tu última vida).
# * `truncated` (bool): True si el episodio se trunca debido a un límite de tiempo o una razón que no está definida.
# * `info` (dict): información de diagnóstico útil para la depuración. A veces puede ser útil para el aprendizaje (por ejemplo, podría contener las probabilidades crudas detrás del último cambio de estado del entorno). Sin embargo, no se permite usar esto para el aprendizaje en las evaluaciones oficiales de tu agente.
#
# Esto es simplemente una implementación del clásico "bucle agente-entorno". En cada paso de tiempo, el agente elige una acción, y el entorno devuelve una observación y una recompensa.

# %%
env = gym.make('MountainCar-v0')

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Espacio de Acciones
#
# Hay 3 acciones discretas determinísticas:
#
# | Num | Observación          | Valor | Unidad       |
# |-----|----------------------|-------|--------------|
# | 0   | Acelerar a la izquierda | Inf   | posición (m) |
# | 1   | No acelerar              | Inf   | posición (m) |
# | 2   | Acelerar a la derecha    | Inf   | posición (m) |

# %%
# env = gym.make('MountainCar-v0', render_mode='human')
print(env.observation_space.shape)
# Out:
# (2,)

# %% [markdown]
# ## Espacio de Observación
#
# La observación es un ndarray con forma (2,), donde los elementos corresponden a lo siguiente:
#
# | Num | Observación                    | Mínimo | Máximo | Unidad        |
# |-----|--------------------------------|--------|--------|---------------|
# | 0   | posición del coche a lo largo del eje x | -Inf   | Inf    | posición (m) |
# | 1   | velocidad del coche             | -Inf   | Inf    | velocidad (m) |

# %%
import numpy as np
np.random.choice(np.array([1,2,3]))
# Out:
# np.int64(2)

# %%
# import gym
env = gym.make('MountainCar-v0', render_mode='human')
for i_episode in range(5):
    # Reset del entorno
    print("Intento", i_episode)
    observation = env.reset()
    for t in range(10000):
        if t % 10 == 0:
            print("Accion", t)
            print("Observación", observation)
        # Visualizar ejercicio
        env.render()
        # Print del estado
        # print(observation)
        # Guarda en la variable action una de las acciones posibles elegida al azar
        action = env.action_space.sample()
        # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
        # que nos indica que ha alcanzado su objetivo e info debug
        observation, reward, done, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Intento 0
# Accion 0
# Observación (array([-0.5279068,  0.       ], dtype=float32), {})
# Accion 10
# Observación [-5.2375275e-01  1.5747323e-04]
# Accion 20
# Observación [-0.5373386  -0.00375608]
# Accion 30
# Observación [-0.56795484 -0.00157906]
# Accion 40
# Observación [-0.56791663  0.00308491]
# Accion 50
# Observación [-0.51512355  0.00566481]
# Accion 60
# Observación [-0.4814969   0.00386311]
# Accion 70
# Observación [-0.4584357   0.00083631]
# Accion 80
# Observación [-0.4717045  -0.00389422]
# Accion 90
# Observación [-0.5164442  -0.00544638]
# Accion 100
# Observación [-0.5762184 -0.0059278]
# Accion 110
# Observación [-0.6003841   0.00131783]
# Accion 120
# Observación [-5.9147328e-01 -3.9063534e-04]
# Accion 130
# Observación [-0.5872336   0.00067104]
# Accion 140
# Observación [-0.54113775  0.00827413]
# Accion 150
# Observación [-0.46243235  0.00681628]
# Accion 160
# Observación [-4.4266516e-01  2.3638095e-04]
# Accion 170
# Observación [-0.46025023 -0.00337906]
# Accion 180
# Observación [-0.51523864 -0.00644676]
# Accion 190
# Observación [-0.5999856  -0.00929062]
# Accion 200
# Observación [-6.4097017e-01  4.6173928e-04]
# Accion 210
# Observación [-0.5844501   0.00868083]
# Accion 220
# Observación [-0.48493138  0.00887271]
# Accion 230
# Observación [-0.40282938  0.004887  ]
# Accion 240
# Observación [-0.41088217 -0.00412843]
# Accion 250
# Observación [-0.48523793 -0.01044624]
# Accion 260
# Observación [-0.57512593 -0.00805369]
# Accion 270
# Observación [-0.6385152  -0.00161035]
# Accion 280
# Observación [-0.633729    0.00411029]
# Accion 290
# Observación [-0.549336    0.01182209]
# Accion 300
# Observación [-0.429726    0.00941163]
# Accion 310
# Observación [-0.38424996  0.00262258]
# Accion 320
# Observación [-0.41896987 -0.00702965]
# Accion 330
# Observación [-0.5297088  -0.01132779]
# Accion 340
# Observación [-0.6007358  -0.00307438]
# Accion 350
# Observación [-0.6115757   0.00243759]
# Accion 360
# Observación [-0.5538404   0.00955878]
# Accion 370
# Observación [-0.43104833  0.01183594]
# Accion 380
# Observación [-0.35524625  0.00401161]
# Accion 390
# Observación [-0.35658315 -0.00568906]
# Accion 400
# Observación [-0.48248816 -0.01641651]
# Accion 410
# Observación [-0.6415847  -0.01286665]
# Accion 420
# Observación [-0.7145619  -0.00341868]
# Accion 430
# Observación [-0.6883685   0.00587662]
# Accion 440
# Observación [-0.55863345  0.01836777]
# Accion 450
# Observación [-0.37265834  0.01549972]
# Accion 460
# Observación [-0.26983413  0.00501976]
# Accion 470
# Observación [-0.29604113 -0.01138174]
# Accion 480
# Observación [-0.49881387 -0.0248826 ]
# Accion 490
# Observación [-0.71556866 -0.01598601]
# Accion 500
# Observación [-7.934224e-01  5.875810e-04]
# Accion 510
# Observación [-0.671194    0.02054868]
# Accion 520
# Observación [-0.42327803  0.02551769]
# Accion 530
# Observación [-0.24537075  0.01106445]
# Accion 540
# Observación [-0.23910737 -0.00940286]
# Accion 550
# Observación [-0.41657862 -0.02450003]
# Accion 560
# Observación [-0.6778772  -0.02684425]
# Accion 570
# Observación [-0.8536841 -0.008074 ]
# Accion 580
# Observación [-0.8029875   0.01364087]
# Accion 590
# Observación [-0.61208963  0.023644  ]
# Accion 600
# Observación [-0.34280074  0.02431928]
# Accion 610
# Observación [-0.17560035  0.00956426]
# Accion 620
# Observación [-0.23120324 -0.01685185]
# Accion 630
# Observación [-0.495965   -0.03167731]
# Accion 640
# Observación [-0.772569   -0.01991093]
# Accion 650
# Observación [-0.87634534 -0.00198706]
# Accion 660
# Observación [-0.77518976  0.02071342]
# Accion 670
# Observación [-0.48852783  0.03207979]
# Accion 680
# Observación [-0.22776291  0.01850683]
# Accion 690
# Observación [-0.17156447 -0.0057934 ]
# Accion 700
# Observación [-0.3499123  -0.02559966]
# Accion 710
# Observación [-0.6411865  -0.02981185]
# Accion 720
# Observación [-0.87043506 -0.01597055]
# Accion 730
# Observación [-0.8775152   0.00840531]
# Accion 740
# Observación [-0.68131477  0.02579564]
# Accion 750
# Observación [-0.37285358  0.0303754 ]
# Accion 760
# Observación [-0.12980908  0.01647503]
# Accion 770
# Observación [-0.06080529 -0.00472348]
# Accion 780
# Observación [-0.22931364 -0.02593193]
# Accion 790
# Observación [-0.55769336 -0.0334627 ]
# Accion 800
# Observación [-0.82647175 -0.01987653]
# Accion 810
# Observación [-0.9122985  0.0031152]
# Accion 820
# Observación [-0.7686836   0.02340146]
# Accion 830
# Observación [-0.47970188  0.02985541]
# Accion 840
# Observación [-0.22919667  0.01921732]
# Accion 850
# Observación [-0.14530966  0.00071941]
# Accion 860
# Observación [-0.2513031  -0.01974671]
# Accion 870
# Observación [-0.5021628  -0.02838805]
# Accion 880
# Observación [-0.76901    -0.02073549]
# Accion 890
# Observación [-8.7035924e-01 -8.5959997e-04]
# Accion 900
# Observación [-0.76886135  0.01945644]
# Accion 910
# Observación [-0.5183385   0.02829563]
# Accion 920
# Observación [-0.22982402  0.0255074 ]
# Accion 930
# Observación [-0.09046593  0.00517281]
# Accion 940
# Observación [-0.15275627 -0.01664811]
# Accion 950
# Observación [-0.41773847 -0.03195429]
# Accion 960
# Observación [-0.74838364 -0.03067214]
# Accion 970
# Observación [-0.9584021 -0.0099069]
# Accion 980
# Observación [-0.9290119   0.01330798]
# Accion 990
# Observación [-0.6701601   0.03359608]
# Accion 1000
# Observación [-0.31044644  0.03346047]
# Accion 1010
# Observación [-0.04932097  0.01651819]
# Accion 1020
# Observación [-0.036158   -0.01242111]
# Accion 1030
# Observación [-0.29827517 -0.03790718]
# Accion 1040
# Observación [-0.71842957 -0.04062784]
# Accion 1050
# Observación [-0.9929336  -0.01702638]
# Accion 1060
# Observación [-1.016363    0.00889026]
# Accion 1070
# Observación [-0.7880644   0.03411617]
# Accion 1080
# Observación [-0.38247392  0.04005834]
# Accion 1090
# Observación [-0.06369046  0.02123229]
# Accion 1100
# Observación [-0.00507995 -0.00468263]
# Accion 1110
# Observación [-0.17765681 -0.02798583]
# Accion 1120
# Observación [-0.53667617 -0.03787536]
# Accion 1130
# Observación [-0.85216874 -0.02431215]
# Accion 1140
# Observación [-0.9387621   0.00461775]
# Accion 1150
# Observación [-0.754191    0.02703192]
# Accion 1160
# Observación [-0.43505025  0.0324149 ]
# Accion 1170
# Observación [-0.18640555  0.02003685]
# Accion 1180
# Observación [-9.9380001e-02 -3.9651586e-06]
# Accion 1190
# Observación [-0.22354156 -0.02276779]
# Accion 1200
# Observación [-0.5172472 -0.0351098]
# Accion 1210
# Observación [-0.8156324 -0.0233164]
# Accion 1220
# Observación [-0.94057083 -0.00428052]
# Accion 1230
# Observación [-0.86356205  0.01804433]
# Accion 1240
# Observación [-0.5900345   0.03357349]
# Accion 1250
# Observación [-0.27693227  0.0266734 ]
# Accion 1260
# Observación [-0.13325532  0.00605604]
# Accion 1270
# Observación [-0.18885496 -0.01365523]
# Accion 1280
# Observación [-0.4304198  -0.03187507]
# Accion 1290
# Observación [-0.74917465 -0.02678292]
# Accion 1300
# Observación [-0.9270716  -0.00746341]
# Accion 1310
# Observación [-0.8515318   0.01954993]
# Accion 1320
# Observación [-0.55263525  0.03565596]
# Accion 1330
# Observación [-0.24461848  0.02520616]
# Accion 1340
# Observación [-0.10599353  0.005399  ]
# Accion 1350
# Observación [-0.2083466  -0.02372876]
# Accion 1360
# Observación [-0.51356745 -0.03451654]
# Accion 1370
# Observación [-0.82711226 -0.02477537]
# Accion 1380
# Observación [-9.4985741e-01 -2.7671727e-04]
# Accion 1390
# Observación [-0.8735355  0.0151005]
# Accion 1400
# Observación [-0.60403794  0.0333226 ]
# Accion 1410
# Observación [-0.29788697  0.02685285]
# Accion 1420
# Observación [-0.14311825  0.00585611]
# Accion 1430
# Observación [-0.22265798 -0.01833736]
# Accion 1440
# Observación [-0.50060076 -0.03333193]
# Accion 1450
# Observación [-0.8251128  -0.02614438]
# Accion 1460
# Observación [-1.0090451  -0.01022532]
# Accion 1470
# Observación [-1.0072216   0.00970651]
# Accion 1480
# Observación [-0.7769131   0.03464814]
# Accion 1490
# Observación [-0.38099566  0.0411736 ]
# Accion 1500
# Observación [-0.03797563  0.02713468]
# Accion 1510
# Observación [0.1093849  0.00561689]
# Accion 1520
# Observación [ 0.02883152 -0.02033758]
# Accion 1530
# Observación [-0.299972   -0.04229231]
# Accion 1540
# Observación [-0.7666859  -0.04537439]
# Accion 1550
# Observación [-1.1000143  -0.02072126]
# Accion 1560
# Observación [-1.1942703  0.0044879]
# Accion 1570
# Observación [-1.0010295   0.03144469]
# Accion 1580
# Observación [-0.5778396   0.04778954]
# Accion 1590
# Observación [-0.15345134  0.03378735]
# Accion 1600
# Observación [0.04420874 0.00939247]
# Accion 1610
# Observación [ 0.0051456  -0.01436973]
# Accion 1620
# Observación [-0.25620288 -0.03685029]
# Accion 1630
# Observación [-0.71701163 -0.04849447]
# Accion 1640
# Observación [-1.103268   -0.02590912]
# Accion 1650
# Observación [-1.1671395   0.01134212]
# Accion 1660
# Observación [-0.925398    0.03475499]
# Accion 1670
# Observación [-0.47331327  0.04833346]
# Accion 1680
# Observación [-0.05899304  0.03135068]
# Accion 1690
# Observación [0.12689647 0.00793155]
# Accion 1700
# Observación [ 0.08041887 -0.01525571]
# Accion 1710
# Observación [-0.18038727 -0.03562757]
# Accion 1720
# Observación [-0.6141805  -0.04605519]
# Accion 1730
# Observación [-1.020216  -0.0292177]
# Accion 1740
# Observación [-1.1935816  -0.00609958]
# Accion 1750
# Observación [-1.1230654   0.01941944]
# Accion 1760
# Observación [-0.78190774  0.04407408]
# Accion 1770
# Observación [-0.33120576  0.04177064]
# Accion 1780
# Observación [-0.01088247  0.02177793]
# Accion 1790
# Observación [0.08476635 0.00018202]
# Accion 1800
# Observación [-0.0712697  -0.02646999]
# Accion 1810
# Observación [-0.4734581  -0.04946002]
# Accion 1820
# Observación [-0.9393614  -0.04048667]
# Accion 1830
# Observación [-1.2  0. ]
# Accion 1840
# Observación [-1.0799602   0.02330842]
# Accion 1850
# Observación [-0.7038416   0.04868874]
# Accion 1860
# Observación [-0.20711534  0.0465478 ]
# Accion 1870
# Observación [0.10938343 0.01973195]
# Accion 1880
# Observación [ 0.18814598 -0.0012871 ]
# Accion 1890
# Observación [ 0.03316223 -0.02691701]
# Accion 1900
# Observación [-0.3680986  -0.04765351]
# Accion 1910
# Observación [-0.865833   -0.04578989]
# Accion 1920
# Observación [-1.1987581  0.0012419]
# Accion 1930
# Observación [-1.063475    0.02572244]
# Accion 1940
# Observación [-0.68038625  0.04641938]
# Accion 1950
# Observación [-0.22469863  0.04065708]
# Accion 1960
# Observación [0.04503933 0.01612507]
# Accion 1970
# Observación [ 0.08609868 -0.00316011]
# Accion 1980
# Observación [-0.10649796 -0.03078607]
# Accion 1990
# Observación [-0.520364   -0.04753361]
# Accion 2000
# Observación [-0.96937597 -0.03799821]
# Accion 2010
# Observación [-1.1967582  0.0032419]
# Accion 2020
# Observación [-1.049484    0.02491469]
# Accion 2030
# Observación [-0.6687532   0.04624687]
# Accion 2040
# Observación [-0.21866366  0.03971581]
# Accion 2050
# Observación [0.03425173 0.01414163]
# Accion 2060
# Observación [ 0.02797215 -0.01351954]
# Accion 2070
# Observación [-0.2465912  -0.03822307]
# Accion 2080
# Observación [-0.66957545 -0.04125493]
# Accion 2090
# Observación [-0.99021053 -0.02209957]
# Accion 2100
# Observación [-1.0603126   0.00482578]
# Accion 2110
# Observación [-0.86119056  0.03112615]
# Accion 2120
# Observación [-0.4817054   0.04102203]
# Accion 2130
# Observación [-0.13618207  0.02698587]
# Accion 2140
# Observación [0.03267575 0.00850325]
# Accion 2150
# Observación [ 0.00332207 -0.01431055]
# Accion 2160
# Observación [-0.28258115 -0.03844358]
# Accion 2170
# Observación [-0.7019444  -0.04006049]
# Accion 2180
# Observación [-0.98993206 -0.01803765]
# Accion 2190
# Observación [-1.0454514   0.00489238]
# Accion 2200
# Observación [-0.8725516  0.0292608]
# Accion 2210
# Observación [-0.49615693  0.04091439]
# Accion 2220
# Observación [-0.16965982  0.0240069 ]
# Accion 2230
# Observación [-0.06052991  0.00131238]
# Accion 2240
# Observación [-0.17227945 -0.02271133]
# Accion 2250
# Observación [-0.51139665 -0.038984  ]
# Accion 2260
# Observación [-0.88675016 -0.03275111]
# Accion 2270
# Observación [-1.0868341  -0.00844658]
# Accion 2280
# Observación [-1.0279045   0.01739241]
# Accion 2290
# Observación [-0.7311123   0.03970686]
# Accion 2300
# Observación [-0.3156698   0.03904022]
# Accion 2310
# Observación [-0.02281072  0.01781413]
# Accion 2320
# Observación [ 0.01510148 -0.00812305]
# Accion 2330
# Observación [-0.20656644 -0.03224013]
# Accion 2340
# Observación [-0.59065324 -0.0405762 ]
# Accion 2350
# Observación [-0.91659576 -0.02434916]
# Accion 2360
# Observación [-1.0339477e+00  1.3985224e-04]
# Accion 2370
# Observación [-0.897282    0.02365252]
# Accion 2380
# Observación [-0.56990224  0.03827333]
# Accion 2390
# Observación [-0.200968    0.03138892]
# Accion 2400
# Observación [-0.01692059  0.0088279 ]
# Accion 2410
# Observación [-0.03108569 -0.0111608 ]
# Accion 2420
# Observación [-0.29523373 -0.03778155]
# Accion 2430
# Observación [-0.69182634 -0.03724666]
# Accion 2440
# Observación [-0.9697826  -0.01572131]
# Accion 2450
# Observación [-0.9754543   0.01296595]
# Accion 2460
# Observación [-0.72846663  0.03344273]
# Accion 2470
# Observación [-0.35815904  0.03851608]
# Accion 2480
# Observación [-0.03339658  0.02469616]
# Accion 2490
# Observación [ 7.3977657e-02 -2.8615303e-05]
# Accion 2500
# Observación [-0.04354887 -0.02173463]
# Accion 2510
# Observación [-0.37512293 -0.04248492]
# Accion 2520
# Observación [-0.8069582  -0.03686184]
# Accion 2530
# Observación [-1.0273774  -0.00886033]
# Accion 2540
# Observación [-0.95082134  0.02099733]
# Accion 2550
# Observación [-0.62350917  0.04069809]
# Accion 2560
# Observación [-0.22642662  0.03362082]
# Accion 2570
# Observación [-0.0215459   0.00951275]
# Accion 2580
# Observación [-0.06568621 -0.01541273]
# Accion 2590
# Observación [-0.32965806 -0.03266476]
# Accion 2600
# Observación [-0.68866324 -0.03496397]
# Accion 2610
# Observación [-0.95142895 -0.01797604]
# Accion 2620
# Observación [-1.0261836e+00  7.1752397e-04]
# Accion 2630
# Observación [-0.85870945  0.02990126]
# Accion 2640
# Observación [-0.46576795  0.04341539]
# Accion 2650
# Observación [-0.12383103  0.02433141]
# Accion 2660
# Observación [-0.00995727  0.0008111 ]
# Accion 2670
# Observación [-0.14137582 -0.0237852 ]
# Accion 2680
# Observación [-0.5203556  -0.04375442]
# Accion 2690
# Observación [-0.9195087  -0.03336171]
# Accion 2700
# Observación [-1.118085   -0.00880984]
# Accion 2710
# Observación [-1.0661825   0.01763121]
# Accion 2720
# Observación [-0.76972693  0.03987902]
# Accion 2730
# Observación [-0.31663743  0.0450871 ]
# Accion 2740
# Observación [0.02438572 0.02542553]
# Accion 2750
# Observación [ 0.13668056 -0.00037875]
# Accion 2760
# Observación [ 0.02332598 -0.02307205]
# Accion 2770
# Observación [-0.32658318 -0.04457914]
# Accion 2780
# Observación [-0.79867905 -0.04230845]
# Accion 2790
# Observación [-1.1338631  -0.02514827]
# Accion 2800
# Observación [-1.1372466  0.0177746]
# Accion 2810
# Observación [-0.8142557  0.0437434]
# Accion 2820
# Observación [-0.34106177  0.04506608]
# Accion 2830
# Observación [0.01963033 0.02501692]
# Accion 2840
# Observación [0.1299107  0.00198948]
# Accion 2850
# Observación [ 0.01671483 -0.02179668]
# Accion 2860
# Observación [-0.32598746 -0.04117883]
# Accion 2870
# Observación [-0.7370135  -0.03780292]
# Accion 2880
# Observación [-1.0066248 -0.0176928]
# Accion 2890
# Observación [-1.052363    0.00726618]
# Accion 2900
# Observación [-0.8627854   0.03159011]
# Accion 2910
# Observación [-0.4685725   0.04419734]
# Accion 2920
# Observación [-0.07191181  0.03145352]
# Accion 2930
# Observación [0.0844754  0.00475951]
# Accion 2940
# Observación [-0.04213933 -0.02580356]
# Accion 2950
# Observación [-0.41296628 -0.04572235]
# Accion 2960
# Observación [-0.8648538  -0.04009598]
# Accion 2970
# Observación [-1.1298397  -0.01301068]
# Accion 2980
# Observación [-1.1103019   0.01295102]
# Accion 2990
# Observación [-0.8354926   0.03813282]
# Accion 3000
# Observación [-0.3971728   0.04320306]
# Accion 3010
# Observación [-0.06612067  0.02375417]
# Accion 3020
# Observación [ 0.02677069 -0.00213   ]
# Accion 3030
# Observación [-0.12844746 -0.02688199]
# Accion 3040
# Observación [-0.5126309  -0.04531487]
# Accion 3050
# Observación [-0.9196979  -0.03304933]
# Accion 3060
# Observación [-1.1513731  -0.01659281]
# Accion 3070
# Observación [-1.1691995   0.01231423]
# Accion 3080
# Observación [-0.9098924   0.03566725]
# Accion 3090
# Observación [-0.4527786   0.04810821]
# Accion 3100
# Observación [-0.03509127  0.030984  ]
# Accion 3110
# Observación [0.11925805 0.00361488]
# Accion 3120
# Observación [ 0.01942872 -0.02326425]
# Accion 3130
# Observación [-0.3457308  -0.04649878]
# Accion 3140
# Observación [-0.84170765 -0.04637783]
# Accion 3150
# Observación [-1.1414096  -0.01651824]
# Accion 3160
# Observación [-1.180496    0.00976769]
# Accion 3170
# Observación [-0.9571718   0.03402399]
# Accion 3180
# Observación [-0.50084966  0.05245152]
# Accion 3190
# Observación [-0.06149158  0.03642121]
# Accion 3200
# Observación [0.15484416 0.01126367]
# Accion 3210
# Observación [ 0.15077361 -0.01145296]
# Accion 3220
# Observación [-0.07266712 -0.0315067 ]
# Accion 3230
# Observación [-0.48977578 -0.04457093]
# Accion 3240
# Observación [-0.9052895  -0.03232899]
# Accion 3250
# Observación [-1.1256542  -0.01290915]
# Accion 3260
# Observación [-1.126511    0.00711276]
# Accion 3270
# Observación [-0.9278961   0.02975858]
# Accion 3280
# Observación [-0.51457447  0.04679218]
# Accion 3290
# Observación [-0.09651589  0.0340208 ]
# Accion 3300
# Observación [0.10448503 0.0074954 ]
# Accion 3310
# Observación [ 0.07261809 -0.01317227]
# Accion 3320
# Observación [-0.20827863 -0.04039491]
# Accion 3330
# Observación [-0.6645809  -0.04719654]
# Accion 3340
# Observación [-1.0492402  -0.02743874]
# Accion 3350
# Observación [-1.1673664   0.00265138]
# Accion 3360
# Observación [-1.0241799   0.02289244]
# Accion 3370
# Observación [-0.65005654  0.04761602]
# Accion 3380
# Observación [-0.18155338  0.04029181]
# Accion 3390
# Observación [0.05530123 0.00915189]
# Accion 3400
# Observación [ 0.02786933 -0.01341567]
# Accion 3410
# Observación [-0.227135   -0.03330418]
# Accion 3420
# Observación [-0.6545972  -0.04398395]
# Accion 3430
# Observación [-0.9736402  -0.02045369]
# Accion 3440
# Observación [-1.0548052   0.00242091]
# Accion 3450
# Observación [-0.92268205  0.02415184]
# Accion 3460
# Observación [-0.5798262   0.04200694]
# Accion 3470
# Observación [-0.16205944  0.03562891]
# Accion 3480
# Observación [0.07077692 0.01335311]
# Accion 3490
# Observación [ 0.05040266 -0.01482596]
# Accion 3500
# Observación [-0.21331148 -0.03799197]
# Accion 3510
# Observación [-0.6631979  -0.04575101]
# Accion 3520
# Observación [-1.02655    -0.02740821]
# Accion 3530
# Observación [-1.1477855  -0.00190991]
# Accion 3540
# Observación [-1.0178037   0.02450559]
# Accion 3550
# Observación [-0.6580521   0.04317307]
# Accion 3560
# Observación [-0.22369678  0.03961622]
# Accion 3570
# Observación [0.06834891 0.0190626 ]
# Accion 3580
# Observación [ 0.09968268 -0.00866887]
# Accion 3590
# Observación [-0.13546523 -0.03617387]
# Accion 3600
# Observación [-0.58967155 -0.04886911]
# Accion 3610
# Observación [-0.9865863  -0.03126932]
# Accion 3620
# Observación [-1.1919577 -0.0099748]
# Accion 3630
# Observación [-1.1173459   0.01679552]
# Accion 3640
# Observación [-0.80474925  0.0437189 ]
# Accion 3650
# Observación [-0.33126345  0.04640705]
# Accion 3660
# Observación [0.01453711 0.0230657 ]
# Accion 3670
# Observación [ 1.2200613e-01 -3.2780506e-05]
# Accion 3680
# Observación [-0.02847668 -0.02719023]
# Accion 3690
# Observación [-0.41593    -0.04518189]
# Accion 3700
# Observación [-0.8546401  -0.03853205]
# Accion 3710
# Observación [-1.1174033  -0.01658259]
# Accion 3720
# Observación [-1.1241666   0.01037315]
# Accion 3730
# Observación [-0.8324266   0.04257308]
# Accion 3740
# Observación [-0.3513299   0.04792223]
# Accion 3750
# Observación [0.01608045 0.02615698]
# Accion 3760
# Observación [0.14513397 0.00228559]
# Accion 3770
# Observación [ 0.06081123 -0.01794063]
# Accion 3780
# Observación [-0.26468945 -0.04356867]
# Accion 3790
# Observación [-0.72508883 -0.04311833]
# Accion 3800
# Observación [-1.0609039  -0.02365727]
# Accion 3810
# Observación [-1.1540544   0.00253761]
# Accion 3820
# Observación [-0.99333453  0.02701191]
# Accion 3830
# Observación [-0.57993764  0.05055032]
# Accion 3840
# Observación [-0.08758739  0.0421278 ]
# Accion 3850
# Observación [0.22283195 0.01965247]
# Accion 3860
# Observación [0.33431545 0.00535695]
# Accion 3870
# Observación [ 0.32866183 -0.00478444]
# Accion 3880
# Observación [ 0.19975476 -0.01924804]
# Accion 3890
# Observación [-0.09371395 -0.04170191]
# Accion 3900
# Observación [-0.6009034  -0.05416356]
# Accion 3910
# Observación [-1.0413505  -0.03322941]
# Accion 3920
# Observación [-1.1835088   0.00875814]
# Accion 3930
# Observación [-0.9403434   0.03498891]
# Accion 3940
# Observación [-0.5155246   0.04720609]
# Accion 3950
# Observación [-0.115516    0.02968023]
# Accion 3960
# Observación [0.06668311 0.00905948]
# Accion 3970
# Observación [ 0.05029145 -0.00932101]
# Accion 3980
# Observación [-0.1789398  -0.03376137]
# Accion 3990
# Observación [-0.5649078  -0.04064145]
# Accion 4000
# Observación [-0.90232605 -0.02678595]
# Accion 4010
# Observación [-1.0273921  -0.00147831]
# Accion 4020
# Observación [-0.88033074  0.02589402]
# Accion 4030
# Observación [-0.5268718  0.0419874]
# Accion 4040
# Observación [-0.13346113  0.03159746]
# Accion 4050
# Observación [0.07696119 0.01110818]
# Accion 4060
# Observación [ 0.05628914 -0.01304752]
# Accion 4070
# Observación [-0.20568188 -0.0362691 ]
# Accion 4080
# Observación [-0.65512705 -0.04760497]
# Accion 4090
# Observación [-1.0363771  -0.02721842]
# Accion 4100
# Observación [-1.1509899e+00 -7.9106435e-04]
# Accion 4110
# Observación [-1.0087541   0.02464631]
# Accion 4120
# Observación [-0.6531732   0.04297474]
# Accion 4130
# Observación [-0.22646964  0.04039832]
# Accion 4140
# Observación [0.08660081 0.02188677]
# Accion 4150
# Observación [ 0.17078257 -0.00172541]
# Accion 4160
# Observación [ 0.04787176 -0.0226667 ]
# Accion 4170
# Observación [-0.34910122 -0.05110085]
# Accion 4180
# Observación [-0.9014586  -0.05215845]
# Accion 4190
# Observación [-1.1932669   0.00449118]
# Accion 4200
# Observación [-1.0008357   0.03146996]
# Accion 4210
# Observación [-0.5506535   0.05233208]
# Accion 4220
# Observación [-0.0549663   0.04121776]
# Accion 4230
# Observación [0.18644322 0.01345069]
# Accion 4240
# Observación [ 0.19405748 -0.00599305]
# Accion 4250
# Observación [ 0.01774095 -0.02675519]
# Accion 4260
# Observación [-0.3826876  -0.04710684]
# Accion 4270
# Observación [-0.8623738  -0.04362067]
# Accion 4280
# Observación [-1.1867381  -0.02072116]
# Accion 4290
# Observación [-1.1082398   0.01984133]
# Accion 4300
# Observación [-0.770112    0.04431162]
# Accion 4310
# Observación [-0.2768708   0.04916997]
# Accion 4320
# Observación [0.0694202  0.02439516]
# Accion 4330
# Observación [0.18583992 0.00077042]
# Accion 4340
# Observación [ 0.05312186 -0.02467009]
# Accion 4350
# Observación [-0.30626276 -0.04670614]
# Accion 4360
# Observación [-0.78209245 -0.0446067 ]
# Accion 4370
# Observación [-1.1105096  -0.02269124]
# Accion 4380
# Observación [-1.1912637   0.00549445]
# Accion 4390
# Observación [-0.98868436  0.03348878]
# Accion 4400
# Observación [-0.56761986  0.04624556]
# Accion 4410
# Observación [-0.11364444  0.03904865]
# Accion 4420
# Observación [0.13044113 0.01468017]
# Accion 4430
# Observación [ 0.14627948 -0.00854692]
# Accion 4440
# Observación [-0.08243859 -0.0346328 ]
# Accion 4450
# Observación [-0.54273254 -0.05020183]
# Accion 4460
# Observación [-0.9928536  -0.03528262]
# Accion 4470
# Observación [-1.2  0. ]
# Accion 4480
# Observación [-1.1115129   0.01713333]
# Accion 4490
# Observación [-0.82617784  0.03718875]
# Accion 4500
# Observación [-0.41262427  0.04144005]
# Accion 4510
# Observación [-0.10332123  0.02119859]
# Accion 4520
# Observación [-0.05270921 -0.00637398]
# Accion 4530
# Observación [-0.2517592  -0.03045606]
# Accion 4540
# Observación [-0.6095453 -0.0386549]
# Accion 4550
# Observación [-0.9339469  -0.02459649]
# Accion 4560
# Observación [-1.0396237e+00  1.0314088e-03]
# Accion 4570
# Observación [-0.8998858   0.02458706]
# Accion 4580
# Observación [-0.5443045   0.03967896]
# Accion 4590
# Observación [-0.20606382  0.02673067]
# Accion 4600
# Observación [-0.07707981  0.00068001]
# Accion 4610
# Observación [-0.20461036 -0.02272782]
# Accion 4620
# Observación [-0.51400876 -0.03469627]
# Accion 4630
# Observación [-0.80547255 -0.02233557]
# Accion 4640
# Observación [-0.8998909   0.00202904]
# Accion 4650
# Observación [-0.75573546  0.02581731]
# Accion 4660
# Observación [-0.4626921   0.03023731]
# Accion 4670
# Observación [-0.18235849  0.0218267 ]
# Accion 4680
# Observación [-0.10722233 -0.00532302]
# Accion 4690
# Observación [-0.27193427 -0.02408986]
# Accion 4700
# Observación [-0.58134943 -0.03345007]
# Accion 4710
# Observación [-0.81925046 -0.01376095]
# Accion 4720
# Observación [-0.8610678   0.00406686]
# Accion 4730
# Observación [-0.72131425  0.01990672]
# Accion 4740
# Observación [-0.47615084  0.02658245]
# Accion 4750
# Observación [-0.2584951   0.01436534]
# Accion 4760
# Observación [-0.21014582 -0.00538377]
# Accion 4770
# Observación [-0.36914238 -0.02576284]
# Accion 4780
# Observación [-0.661104   -0.02866888]
# Accion 4790
# Observación [-0.8540058 -0.0114512]
# Accion 4800
# Observación [-0.87981474  0.00651919]
# Accion 4810
# Observación [-0.7019126   0.02336645]
# Accion 4820
# Observación [-0.4256753   0.02854606]
# Accion 4830
# Observación [-0.21740438  0.01333722]
# Accion 4840
# Observación [-0.18035096 -0.00592447]
# Accion 4850
# Observación [-0.34325835 -0.02350819]
# Accion 4860
# Observación [-0.6142857  -0.02799423]
# Accion 4870
# Observación [-0.82887566 -0.01420375]
# Accion 4880
# Observación [-0.8584703   0.00905238]
# Accion 4890
# Observación [-0.66361827  0.02854574]
# Accion 4900
# Observación [-0.36152226  0.02771237]
# Accion 4910
# Observación [-0.17877033  0.01147532]
# Accion 4920
# Observación [-0.22348863 -0.01503357]
# Accion 4930
# Observación [-0.4516688 -0.028327 ]
# Accion 4940
# Observación [-0.7141233  -0.01928384]
# Accion 4950
# Observación [-0.8491321  -0.00882376]
# Accion 4960
# Observación [-0.8130749   0.01398394]
# Accion 4970
# Observación [-0.5872688   0.02793957]
# Accion 4980
# Observación [-0.31097898  0.02422831]
# Accion 4990
# Observación [-0.16304047  0.00602402]
# Accion 5000
# Observación [-0.21954016 -0.01687405]
# Accion 5010
# Observación [-0.46515736 -0.031045  ]
# Accion 5020
# Observación [-0.7574106  -0.02665573]
# Accion 5030
# Observación [-0.9028149  -0.00448469]
# Accion 5040
# Observación [-0.82087123  0.01643043]
# Accion 5050
# Observación [-0.58108073  0.03139192]
# Accion 5060
# Observación [-0.27354428  0.02624363]
# Accion 5070
# Observación [-0.11883418  0.00527441]
# Accion 5080
# Observación [-0.19785807 -0.01661549]
# Accion 5090
# Observación [-0.46291324 -0.02931935]
# Accion 5100
# Observación [-0.75021183 -0.02602112]
# Accion 5110
# Observación [-0.9083851 -0.0069785]
# Accion 5120
# Observación [-0.83024603  0.01737783]
# Accion 5130
# Observación [-0.5661277   0.03101533]
# Accion 5140
# Observación [-0.27658278  0.02530211]
# Accion 5150
# Observación [-0.14023162  0.00377192]
# Accion 5160
# Observación [-0.21890727 -0.0184953 ]
# Accion 5170
# Observación [-0.50863075 -0.03438433]
# Accion 5180
# Observación [-0.82221884 -0.02488404]
# Accion 5190
# Observación [-0.96322185 -0.00233921]
# Accion 5200
# Observación [-0.8727124   0.02035387]
# Accion 5210
# Observación [-0.5524394   0.03693205]
# Accion 5220
# Observación [-0.23841023  0.02325504]
# Accion 5230
# Observación [-0.10049079  0.00424847]
# Accion 5240
# Observación [-0.1746219  -0.01926247]
# Accion 5250
# Observación [-0.45430523 -0.0351467 ]
# Accion 5260
# Observación [-0.78985524 -0.02898042]
# Accion 5270
# Observación [-0.947085   -0.00420887]
# Accion 5280
# Observación [-0.8777008   0.01729168]
# Accion 5290
# Observación [-0.60769033  0.03366645]
# Accion 5300
# Observación [-0.2656489   0.02933897]
# Accion 5310
# Observación [-0.06129345  0.0094546 ]
# Accion 5320
# Observación [-0.11213989 -0.01506384]
# Accion 5330
# Observación [-0.37768906 -0.03455613]
# Accion 5340
# Observación [-0.7422554  -0.03525847]
# Accion 5350
# Observación [-0.98541343 -0.01222323]
# Accion 5360
# Observación [-0.989388    0.00957411]
# Accion 5370
# Observación [-0.777049    0.03020163]
# Accion 5380
# Observación [-0.42402178  0.03604165]
# Accion 5390
# Observación [-0.14470023  0.01911797]
# Accion 5400
# Observación [-0.0875235  -0.00576769]
# Accion 5410
# Observación [-0.28528702 -0.02767293]
# Accion 5420
# Observación [-0.6250757  -0.03731332]
# Accion 5430
# Observación [-0.9079199  -0.01916926]
# Accion 5440
# Observación [-0.9316179   0.01161213]
# Accion 5450
# Observación [-0.69873714  0.03274215]
# Accion 5460
# Observación [-0.32700017  0.03522277]
# Accion 5470
# Observación [-0.07220629  0.01591722]
# Accion 5480
# Observación [-0.0550168  -0.00885437]
# Accion 5490
# Observación [-0.2550268  -0.02874441]
# Accion 5500
# Observación [-0.6106849  -0.03794084]
# Accion 5510
# Observación [-0.91692114 -0.02113998]
# Accion 5520
# Observación [-1.0186626e+00  2.5731919e-04]
# Accion 5530
# Observación [-0.8965553   0.02062245]
# Accion 5540
# Observación [-0.5900798   0.03589952]
# Accion 5550
# Observación [-0.2626167   0.02753025]
# Accion 5560
# Observación [-0.09296967  0.00584263]
# Accion 5570
# Observación [-0.13689888 -0.01310897]
# Accion 5580
# Observación [-0.38995972 -0.0326441 ]
# Accion 5590
# Observación [-0.7401263  -0.03271051]
# Accion 5600
# Observación [-0.95482993 -0.01214475]
# Accion 5610
# Observación [-0.92084444  0.01605369]
# Accion 5620
# Observación [-0.6584217   0.03069928]
# Accion 5630
# Observación [-0.35047194  0.02935272]
# Accion 5640
# Observación [-0.16498299  0.00827229]
# Accion 5650
# Observación [-0.21650474 -0.01554657]
# Accion 5660
# Observación [-0.45474446 -0.02810141]
# Accion 5670
# Observación [-0.7502899  -0.02648017]
# Accion 5680
# Observación [-0.91761255 -0.0073091 ]
# Accion 5690
# Observación [-0.8925053   0.00992474]
# Accion 5700
# Observación [-0.6639003   0.03235029]
# Accion 5710
# Observación [-0.3309145   0.02925248]
# Accion 5720
# Observación [-0.16094834  0.00854295]
# Accion 5730
# Observación [-0.19637921 -0.01367282]
# Accion 5740
# Observación [-0.45938522 -0.03290325]
# Accion 5750
# Observación [-0.7424994  -0.02159096]
# Accion 5760
# Observación [-0.864549   -0.00262849]
# Accion 5770
# Observación [-0.7611249   0.02161066]
# Accion 5780
# Observación [-0.4808222   0.02879163]
# Accion 5790
# Observación [-0.24979803  0.01770904]
# Accion 5800
# Observación [-0.19148102 -0.00149943]
# Accion 5810
# Observación [-0.32932428 -0.02233006]
# Accion 5820
# Observación [-0.6251275  -0.03222053]
# Accion 5830
# Observación [-0.8833503  -0.01763822]
# Accion 5840
# Observación [-0.94657195  0.0047895 ]
# Accion 5850
# Observación [-0.77623075  0.02471514]
# Accion 5860
# Observación [-0.46092606  0.03291165]
# Accion 5870
# Observación [-0.2109273   0.01791399]
# Accion 5880
# Observación [-0.13955832 -0.00314583]
# Accion 5890
# Observación [-0.31440803 -0.0265874 ]
# Accion 5900
# Observación [-0.6086466 -0.0291818]
# Accion 5910
# Observación [-0.83655244 -0.01518281]
# Accion 5920
# Observación [-0.8771319   0.00442583]
# Accion 5930
# Observación [-0.72586346  0.02398405]
# Accion 5940
# Observación [-0.44274926  0.02869871]
# Accion 5950
# Observación [-0.22832477  0.01438721]
# Accion 5960
# Observación [-0.19539857 -0.00744491]
# Accion 5970
# Observación [-0.35314652 -0.02019932]
# Accion 5980
# Observación [-0.5873625  -0.02636341]
# Accion 5990
# Observación [-0.7869307  -0.01265432]
# Accion 6000
# Observación [-0.8001703  0.0093245]
# Accion 6010
# Observación [-0.60539126  0.02428091]
# Accion 6020
# Observación [-0.38540652  0.01872706]
# Accion 6030
# Observación [-0.25720647  0.00618602]
# Accion 6040
# Observación [-0.2773911  -0.01214266]
# Accion 6050
# Observación [-0.48257214 -0.02593225]
# Accion 6060
# Observación [-0.74532825 -0.02320971]
# Accion 6070
# Observación [-0.85946566 -0.00110828]
# Accion 6080
# Observación [-0.7644355   0.01786428]
# Accion 6090
# Observación [-0.50762075  0.02826086]
# Accion 6100
# Observación [-0.23283416  0.02097372]
# Accion 6110
# Observación [-0.12858148 -0.00086803]
# Accion 6120
# Observación [-0.2516747  -0.02167889]
# Accion 6130
# Observación [-0.56543475 -0.03564278]
# Accion 6140
# Observación [-0.87372786 -0.02364425]
# Accion 6150
# Observación [-0.97407675 -0.00212462]
# Accion 6160
# Observación [-0.86112213  0.02052351]
# Accion 6170
# Observación [-0.56341136  0.03510517]
# Accion 6180
# Observación [-0.24511346  0.02518983]
# Accion 6190
# Observación [-0.09791896  0.00530002]
# Accion 6200
# Observación [-0.16966961 -0.01622532]
# Accion 6210
# Observación [-0.43381757 -0.03280368]
# Accion 6220
# Observación [-0.74768704 -0.0265569 ]
# Accion 6230
# Observación [-0.9025113 -0.0067598]
# Accion 6240
# Observación [-0.84553283  0.01666416]
# Accion 6250
# Observación [-0.5922279   0.02945725]
# Accion 6260
# Observación [-0.3207257   0.02315865]
# Accion 6270
# Observación [-0.18341118  0.00351638]
# Accion 6280
# Observación [-0.2545726  -0.01504457]
# Accion 6290
# Observación [-0.47402215 -0.02671978]
# Accion 6300
# Observación [-0.7528607  -0.02280985]
# Accion 6310
# Observación [-0.86766297 -0.00248552]
# Accion 6320
# Observación [-0.7805089   0.01691057]
# Accion 6330
# Observación [-0.52414924  0.03070475]
# Accion 6340
# Observación [-0.23955129  0.02208556]
# Accion 6350
# Observación [-0.12380193  0.0024361 ]
# Accion 6360
# Observación [-0.24002703 -0.02385782]
# Accion 6370
# Observación [-0.5259959 -0.0311346]
# Accion 6380
# Observación [-0.79244834 -0.02078685]
# Accion 6390
# Observación [-0.8874485  0.0010625]
# Accion 6400
# Observación [-0.7362612   0.02308931]
# Accion 6410
# Observación [-0.46664682  0.02780206]
# Accion 6420
# Observación [-0.22814292  0.01767167]
# Accion 6430
# Observación [-0.14547326  0.00021307]
# Accion 6440
# Observación [-0.24777243 -0.01832855]
# Accion 6450
# Observación [-0.5290369  -0.03358047]
# Accion 6460
# Observación [-0.81537044 -0.0212543 ]
# Accion 6470
# Observación [-0.9329076  -0.00228885]
# Accion 6480
# Observación [-0.8559613   0.01564331]
# Accion 6490
# Observación [-0.6069975   0.02925006]
# Accion 6500
# Observación [-0.3025926   0.02835138]
# Accion 6510
# Observación [-0.1297601   0.00826929]
# Accion 6520
# Observación [-0.19020279 -0.01660594]
# Accion 6530
# Observación [-0.44229525 -0.03232089]
# Accion 6540
# Observación [-0.7582377  -0.02752048]
# Accion 6550
# Observación [-0.92579234 -0.00698946]
# Accion 6560
# Observación [-0.8420857   0.02087866]
# Accion 6570
# Observación [-0.5327608   0.03593917]
# Accion 6580
# Observación [-0.24603812  0.02162734]
# Accion 6590
# Observación [-0.14678265 -0.00059781]
# Accion 6600
# Observación [-0.28273797 -0.02243079]
# Accion 6610
# Observación [-0.53960615 -0.02774143]
# Accion 6620
# Observación [-0.76715636 -0.01864005]
# Accion 6630
# Observación [-8.453350e-01  5.962514e-04]
# Accion 6640
# Observación [-0.73578954  0.01839393]
# Accion 6650
# Observación [-0.4969236   0.02540423]
# Accion 6660
# Observación [-0.2921237   0.01304187]
# Accion 6670
# Observación [-0.26135674 -0.00449214]
# Accion 6680
# Observación [-0.38877726 -0.01747314]
# Accion 6690
# Observación [-0.58979344 -0.01873304]
# Accion 6700
# Observación [-0.7420202  -0.00833855]
# Accion 6710
# Observación [-0.7341868   0.00529597]
# Accion 6720
# Observación [-0.62245107  0.01427343]
# Accion 6730
# Observación [-0.4514235  0.0158446]
# Accion 6740
# Observación [-0.3297048   0.00719864]
# Accion 6750
# Observación [-0.31395578 -0.00460109]
# Accion 6760
# Observación [-0.44863588 -0.02019089]
# Accion 6770
# Observación [-0.6535092  -0.01878504]
# Accion 6780
# Observación [-0.7771715  -0.00497102]
# Accion 6790
# Observación [-0.72869116  0.01281659]
# Accion 6800
# Observación [-0.53841907  0.02299555]
# Accion 6810
# Observación [-0.30340225  0.02006521]
# Accion 6820
# Observación [-0.19079259  0.00231295]
# Accion 6830
# Observación [-0.2758237  -0.01672768]
# Accion 6840
# Observación [-0.48552677 -0.02402091]
# Accion 6850
# Observación [-0.6923096 -0.0176378]
# Accion 6860
# Observación [-0.808275   -0.00254598]
# Accion 6870
# Observación [-0.7213177   0.02031597]
# Accion 6880
# Observación [-0.46501917  0.02544876]
# Accion 6890
# Observación [-0.27164638  0.01333336]
# Accion 6900
# Observación [-0.24419704 -0.00630047]
# Accion 6910
# Observación [-0.363261   -0.01742832]
# Accion 6920
# Observación [-0.58915937 -0.02296286]
# Accion 6930
# Observación [-0.7776176  -0.01473434]
# Accion 6940
# Observación [-0.8518634  -0.00123581]
# Accion 6950
# Observación [-0.72783345  0.0208008 ]
# Accion 6960
# Observación [-0.43899107  0.0317614 ]
# Accion 6970
# Observación [-0.21381484  0.01385173]
# Accion 6980
# Observación [-0.1896082  -0.00732495]
# Accion 6990
# Observación [-0.3678078  -0.02727338]
# Accion 7000
# Observación [-0.7010046  -0.03506153]
# Accion 7010
# Observación [-0.94564694 -0.01466012]
# Accion 7020
# Observación [-0.94597936  0.01060597]
# Accion 7030
# Observación [-0.70205265  0.0330946 ]
# Accion 7040
# Observación [-0.3363567   0.03510141]
# Accion 7050
# Observación [-0.08958542  0.01432815]
# Accion 7060
# Observación [-0.11141696 -0.01503746]
# Accion 7070
# Observación [-0.39728352 -0.0360653 ]
# Accion 7080
# Observación [-0.74190927 -0.02949833]
# Accion 7090
# Observación [-0.9439966  -0.01005621]
# Accion 7100
# Observación [-0.89509577  0.01671036]
# Accion 7110
# Observación [-0.6164168   0.03471829]
# Accion 7120
# Observación [-0.25002193  0.03350565]
# Accion 7130
# Observación [0.00080545 0.01674638]
# Accion 7140
# Observación [ 0.02535133 -0.00811935]
# Accion 7150
# Observación [-0.188689   -0.03141171]
# Accion 7160
# Observación [-0.6016679  -0.04309443]
# Accion 7170
# Observación [-0.9469354  -0.02479143]
# Accion 7180
# Observación [-1.0536091e+00 -4.4151711e-05]
# Accion 7190
# Observación [-0.9270764   0.02371101]
# Accion 7200
# Observación [-0.58190525  0.03946221]
# Accion 7210
# Observación [-0.21825546  0.03163527]
# Accion 7220
# Observación [-0.01440333  0.01036784]
# Accion 7230
# Observación [-0.05415002 -0.01460006]
# Accion 7240
# Observación [-0.297134   -0.03271019]
# Accion 7250
# Observación [-0.6735608  -0.03584274]
# Accion 7260
# Observación [-0.932868  -0.0176351]
# Accion 7270
# Observación [-0.97033244  0.00666138]
# Accion 7280
# Observación [-0.7842982  0.0271505]
# Accion 7290
# Observación [-0.45945033  0.03347889]
# Accion 7300
# Observación [-0.19508334  0.01793548]
# Accion 7310
# Observación [-0.11790451 -0.0017132 ]
# Accion 7320
# Observación [-0.27063838 -0.0233621 ]
# Accion 7330
# Observación [-0.570732   -0.03318771]
# Accion 7340
# Observación [-0.8636968 -0.0221757]
# Accion 7350
# Observación [-0.94860375  0.00194647]
# Accion 7360
# Observación [-0.78739816  0.02620877]
# Accion 7370
# Observación [-0.45873207  0.03373411]
# Accion 7380
# Observación [-0.17072335  0.0206848 ]
# Accion 7390
# Observación [-0.1229987 -0.0085232]
# Accion 7400
# Observación [-0.32392764 -0.03007986]
# Accion 7410
# Observación [-0.6980366  -0.03655388]
# Accion 7420
# Observación [-0.9766479  -0.01783575]
# Accion 7430
# Observación [-1.0078186   0.00799058]
# Accion 7440
# Observación [-0.8018085  0.0302347]
# Accion 7450
# Observación [-0.43159947  0.03959709]
# Accion 7460
# Observación [-0.09935336  0.0250558 ]
# Accion 7470
# Observación [0.02881691 0.00130116]
# Accion 7480
# Observación [-0.09725988 -0.0265754 ]
# Accion 7490
# Observación [-0.47291622 -0.04494173]
# Accion 7500
# Observación [-0.9096737  -0.03869964]
# Accion 7510
# Observación [-1.1673524  -0.01537454]
# Accion 7520
# Observación [-1.1742117   0.00930516]
# Accion 7530
# Observación [-0.9560293   0.03361654]
# Accion 7540
# Observación [-0.5002343   0.05195722]
# Accion 7550
# Observación [-0.03892539  0.03645581]
# Accion 7560
# Observación [0.17271246 0.00863452]
# Accion 7570
# Observación [ 0.12233086 -0.01614809]
# Accion 7580
# Observación [-0.18425803 -0.0443451 ]
# Accion 7590
# Observación [-0.6801901  -0.04934618]
# Accion 7600
# Observación [-1.0980893  -0.03180276]
# Accion 7610
# Observación [-1.1620593   0.01138129]
# Accion 7620
# Observación [-0.88468945  0.0407073 ]
# Accion 7630
# Observación [-0.38610065  0.05127097]
# Accion 7640
# Observación [0.0237295  0.03036301]
# Accion 7650
# Observación [0.17378114 0.0049857 ]
# Accion 7660
# Observación [ 0.13086484 -0.0137764 ]
# Accion 7670
# Observación [-0.1565129  -0.04002028]
# Accion 7680
# Observación [-0.6505232  -0.05112755]
# Accion 7690
# Observación [-1.0741314  -0.03250057]
# Accion 7700
# Observación [-1.1620593   0.01138129]
# Accion 7710
# Observación [-0.8956144   0.03875008]
# Accion 7720
# Observación [-0.4306342   0.04790755]
# Accion 7730
# Observación [-0.01656182  0.03082115]
# Accion 7740
# Observación [0.16989191 0.00703113]
# Accion 7750
# Observación [ 0.11644788 -0.01595321]
# Accion 7760
# Observación [-0.19456339 -0.04413703]
# Accion 7770
# Observación [-0.7087868  -0.05204822]
# Accion 7780
# Observación [-1.1235054  -0.03156202]
# Accion 7790
# Observación [-1.1354115   0.01605994]
# Accion 7800
# Observación [-0.82823926  0.04217492]
# Accion 7810
# Observación [-0.3264993   0.05087123]
# Accion 7820
# Observación [0.0976423  0.03304289]
# Accion 7830
# Observación [0.31393275 0.0141591 ]
# Accion 7840
# Observación [0.41652665 0.00586602]
# Accion 7850
# Observación [0.4443537  0.00209918]
# Accion 7860
# Observación [ 0.4069038  -0.01028457]
# Accion 7870
# Observación [ 0.2718581  -0.01749973]
# Accion 7880
# Observación [ 0.00149364 -0.03490236]
# Accion 7890
# Observación [-0.46766475 -0.05208708]
# Accion 7900
# Observación [-0.92745095 -0.03721739]
# Accion 7910
# Observación [-1.185581   -0.01590623]
# Accion 7920
# Observación [-1.099011    0.02090521]
# Accion 7930
# Observación [-0.7634563  0.0442613]
# Accion 7940
# Observación [-0.26554647  0.04730617]
# Accion 7950
# Observación [0.11307238 0.02734515]
# Accion 7960
# Observación [0.27667475 0.00897976]
# Accion 7970
# Observación [ 0.28037563 -0.00693523]
# Accion 7980
# Observación [ 0.13807851 -0.02401137]
# Accion 7990
# Observación [-0.24690391 -0.04870701]
# Accion 8000
# Observación [-0.7922058  -0.05298586]
# Accion 8010
# Observación [-1.2  0. ]
# Accion 8020
# Observación [-1.0698172   0.02634854]
# Accion 8030
# Observación [-0.64557135  0.05255993]
# Accion 8040
# Observación [-0.13665788  0.04608865]
# Accion 8050
# Observación [0.18765488 0.02122661]
# Accion 8060
# Observación [0.30344796 0.00417144]
# Accion 8070
# Observación [ 0.23227909 -0.01515948]
# Accion 8080
# Observación [-0.02991393 -0.03673468]
# Accion 8090
# Observación [-0.53759676 -0.05566943]
# Accion 8100
# Observación [-1.0295948  -0.04228795]
# Accion 8110
# Observación [-1.1661209   0.01135127]
# Accion 8120
# Observación [-0.89935213  0.03969447]
# Accion 8130
# Observación [-0.42047104  0.04877415]
# Accion 8140
# Observación [-0.01969872  0.03147973]
# Accion 8150
# Observación [0.16604847 0.00760114]
# Accion 8160
# Observación [ 0.10925185 -0.01559196]
# Accion 8170
# Observación [-0.17467801 -0.03789325]
# Accion 8180
# Observación [-0.6302735  -0.04488321]
# Accion 8190
# Observación [-0.9883266  -0.02493028]
# Accion 8200
# Observación [-1.0929815   0.00389986]
# Accion 8210
# Observación [-0.9183688   0.02762502]
# Accion 8220
# Observación [-0.5192911   0.04660818]
# Accion 8230
# Observación [-0.08692879  0.03392699]
# Accion 8240
# Observación [0.10885258 0.00739411]
# Accion 8250
# Observación [ 0.06834923 -0.01523666]
# Accion 8260
# Observación [-0.22016793 -0.04137965]
# Accion 8270
# Observación [-0.69543827 -0.0488436 ]
# Accion 8280
# Observación [-1.0630552  -0.02507299]
# Accion 8290
# Observación [-1.1813644e+00 -1.7812790e-04]
# Accion 8300
# Observación [-1.0558401   0.02266886]
# Accion 8310
# Observación [-0.7147572   0.04497505]
# Accion 8320
# Observación [-0.22846691  0.04611732]
# Accion 8330
# Observación [0.14326885 0.02767454]
# Accion 8340
# Observación [0.30131847 0.00769998]
# Accion 8350
# Observación [ 0.27780718 -0.00863795]
# Accion 8360
# Observación [ 0.09269531 -0.02762051]
# Accion 8370
# Observación [-0.2805944  -0.04604494]
# Accion 8380
# Observación [-0.7768894  -0.04739052]
# Accion 8390
# Observación [-1.1302133  -0.02348512]
# Accion 8400
# Observación [-1.1595606   0.01363508]
# Accion 8410
# Observación [-0.8833279   0.03797431]
# Accion 8420
# Observación [-0.42453966  0.04971846]
# Accion 8430
# Observación [-0.01372722  0.03045189]
# Accion 8440
# Observación [0.13507254 0.00430601]
# Accion 8450
# Observación [ 0.06822908 -0.01598542]
# Accion 8460
# Observación [-0.2176391  -0.03808122]
# Accion 8470
# Observación [-0.65409344 -0.04372669]
# Accion 8480
# Observación [-0.987687   -0.02096998]
# Accion 8490
# Observación [-1.0946808  -0.00111224]
# Accion 8500
# Observación [-0.9861845   0.01975839]
# Accion 8510
# Observación [-0.6707704  0.0402524]
# Accion 8520
# Observación [-0.27490526  0.03578699]
# Accion 8530
# Observación [-0.03809388  0.01379524]
# Accion 8540
# Observación [-0.03434732 -0.00916217]
# Accion 8550
# Observación [-0.26659405 -0.03419819]
# Accion 8560
# Observación [-0.6628398 -0.0400545]
# Accion 8570
# Observación [-0.9755681  -0.02040603]
# Accion 8580
# Observación [-1.0502285   0.00147238]
# Accion 8590
# Observación [-0.9126639   0.02616379]
# Accion 8600
# Observación [-0.55786633  0.04000028]
# Accion 8610
# Observación [-0.21413884  0.0289327 ]
# Accion 8620
# Observación [-0.06310546  0.00498967]
# Accion 8630
# Observación [-0.14471374 -0.02027142]
# Accion 8640
# Observación [-0.43864444 -0.03630267]
# Accion 8650
# Observación [-0.81613433 -0.03518659]
# Accion 8660
# Observación [-1.053376   -0.01498091]
# Accion 8670
# Observación [-1.0581406  0.0089268]
# Accion 8680
# Observación [-0.8522322   0.03214356]
# Accion 8690
# Observación [-0.4827254   0.03850956]
# Accion 8700
# Observación [-0.13294968  0.02970607]
# Accion 8710
# Observación [0.06357864 0.01019258]
# Accion 8720
# Observación [ 0.02318429 -0.01628612]
# Accion 8730
# Observación [-0.30045748 -0.04332678]
# Accion 8740
# Observación [-0.7775924  -0.04597012]
# Accion 8750
# Observación [-1.1242857 -0.0231414]
# Accion 8760
# Observación [-1.1443856   0.01572073]
# Accion 8770
# Observación [-0.884428    0.03614828]
# Accion 8780
# Observación [-0.44100696  0.04741284]
# Accion 8790
# Observación [-0.0293068   0.03289391]
# Accion 8800
# Observación [0.17050715 0.00901908]
# Accion 8810
# Observación [ 0.1485961  -0.01052628]
# Accion 8820
# Observación [-0.10501167 -0.0376113 ]
# Accion 8830
# Observación [-0.5801398  -0.05133375]
# Accion 8840
# Observación [-1.0067447  -0.03272087]
# Accion 8850
# Observación [-1.1998999  -0.00954912]
# Accion 8860
# Observación [-1.0939274   0.02094416]
# Accion 8870
# Observación [-0.7641366   0.04224242]
# Accion 8880
# Observación [-0.31118286  0.0449287 ]
# Accion 8890
# Observación [0.01470843 0.0232247 ]
# Accion 8900
# Observación [ 0.09922667 -0.00206184]
# Accion 8910
# Observación [-0.0794265  -0.02961107]
# Accion 8920
# Observación [-0.48164448 -0.04703751]
# Accion 8930
# Observación [-0.8871027  -0.03261524]
# Accion 8940
# Observación [-1.0969576  -0.01233507]
# Accion 8950
# Observación [-1.0836505   0.01414634]
# Accion 8960
# Observación [-0.808321    0.03902221]
# Accion 8970
# Observación [-0.36029723  0.04827978]
# Accion 8980
# Observación [0.0158399  0.02563666]
# Accion 8990
# Observación [0.13457406 0.00069401]
# Accion 9000
# Observación [ 0.02258606 -0.02106372]
# Accion 9010
# Observación [-0.30977613 -0.04279859]
# Accion 9020
# Observación [-0.7440787  -0.03992957]
# Accion 9030
# Observación [-1.0398548  -0.01827896]
# Accion 9040
# Observación [-1.0947894   0.00354454]
# Accion 9050
# Observación [-0.93268853  0.02933523]
# Accion 9060
# Observación [-0.54450357  0.04529382]
# Accion 9070
# Observación [-0.15011857  0.03086886]
# Accion 9080
# Observación [0.02644995 0.0074815 ]
# Accion 9090
# Observación [-0.04073494 -0.01744421]
# Accion 9100
# Observación [-0.34605825 -0.04096082]
# Accion 9110
# Observación [-0.80647504 -0.04300248]
# Accion 9120
# Observación [-1.0977459  -0.01772113]
# Accion 9130
# Observación [-1.1571727   0.00421645]
# Accion 9140
# Observación [-0.97976077  0.02867757]
# Accion 9150
# Observación [-0.5709215   0.04749712]
# Accion 9160
# Observación [-0.13906342  0.03685875]
# Accion 9170
# Observación [0.07311862 0.00838363]
# Accion 9180
# Observación [ 0.03004736 -0.01403363]
# Accion 9190
# Observación [-0.2280683  -0.03390624]
# Accion 9200
# Observación [-0.61327547 -0.0375245 ]
# Accion 9210
# Observación [-0.8963278  -0.01787468]
# Accion 9220
# Observación [-0.9612327   0.00182032]
# Accion 9230
# Observación [-0.8074573   0.02451786]
# Accion 9240
# Observación [-0.48774847  0.03469102]
# Accion 9250
# Observación [-0.20076519  0.02242974]
# Accion 9260
# Observación [-0.1281276  -0.00411822]
# Accion 9270
# Observación [-0.29907465 -0.02709591]
# Accion 9280
# Observación [-0.62100697 -0.03431397]
# Accion 9290
# Observación [-0.8692684  -0.01716868]
# Accion 9300
# Observación [-0.9110295  0.0046087]
# Accion 9310
# Observación [-0.735884    0.02618227]
# Accion 9320
# Observación [-0.43544465  0.02978664]
# Accion 9330
# Observación [-0.19678609  0.015469  ]
# Accion 9340
# Observación [-0.16141106 -0.00766637]
# Accion 9350
# Observación [-0.34323058 -0.02579692]
# Accion 9360
# Observación [-0.63710713 -0.02946858]
# Accion 9370
# Observación [-0.85968363 -0.01294621]
# Accion 9380
# Observación [-0.8379      0.01469024]
# Accion 9390
# Observación [-0.6129778   0.02580572]
# Accion 9400
# Observación [-0.3672893   0.02309133]
# Accion 9410
# Observación [-0.2231677  0.006082 ]
# Accion 9420
# Observación [-0.28702047 -0.01591437]
# Accion 9430
# Observación [-0.51424223 -0.02276087]
# Accion 9440
# Observación [-0.73864233 -0.01770521]
# Accion 9450
# Observación [-0.8444823 -0.0035148]
# Accion 9460
# Observación [-0.8048535   0.01279767]
# Accion 9470
# Observación [-0.60958207  0.0249158 ]
# Accion 9480
# Observación [-0.3513443   0.02461143]
# Accion 9490
# Observación [-0.2144758  0.0037003]
# Accion 9500
# Observación [-0.3023249  -0.01611292]
# Accion 9510
# Observación [-0.5406253  -0.02574558]
# Accion 9520
# Observación [-0.7536695  -0.01602198]
# Accion 9530
# Observación [-0.8024649   0.00617968]
# Accion 9540
# Observación [-0.64902663  0.02033869]
# Accion 9550
# Observación [-0.4229086  0.0231523]
# Accion 9560
# Observación [-0.24375416  0.00965436]
# Accion 9570
# Observación [-0.22016005 -0.00400939]
# Accion 9580
# Observación [-0.340989   -0.01857681]
# Accion 9590
# Observación [-0.5687704  -0.02263745]
# Accion 9600
# Observación [-0.7644122  -0.01462258]
# Accion 9610
# Observación [-0.8217629   0.00305532]
# Accion 9620
# Observación [-0.68611735  0.01897724]
# Accion 9630
# Observación [-0.4402217   0.02295521]
# ...
# Accion 8620
# Observación [-0.34090638 -0.00147819]
# Accion 8630
# Observación [-0.41706124 -0.01283839]
# Accion 8640
# Observación [-0.5757795  -0.01649577]
# Accion 8650
# Observación [-0.7035119  -0.00899848]
# Accion 8660
# Observación [-0.7226714   0.00504683]
# Accion 8670
# Observación [-0.6047471   0.01634367]
# Accion 8680
# Observación [-0.42981392  0.01867411]
# Accion 8690
# Observación [-0.3120065   0.00745076]
# Accion 8700
# Observación [-0.29944018 -0.00638638]
# Accion 8710
# Observación [-0.4331307  -0.01771497]
# Accion 8720
# Observación [-0.6426388  -0.02058888]
# Accion 8730
# Observación [-0.7833312 -0.0069636]
# Accion 8740
# Observación [-0.7735236   0.01012828]
# Accion 8750
# Observación [-0.5631668   0.02489519]
# Accion 8760
# Observación [-0.35019007  0.01835151]
# Accion 8770
# Observación [-0.2539182   0.00046168]
# Accion 8780
# Observación [-0.32810804 -0.01441531]
# Accion 8790
# Observación [-0.5229974  -0.02269899]
# Accion 8800
# Observación [-0.72155446 -0.01366879]
# Accion 8810
# Observación [-0.7617475   0.00533883]
# Accion 8820
# Observación [-0.61366093  0.02248826]
# Accion 8830
# Observación [-0.39711243  0.01878423]
# Accion 8840
# Observación [-0.29059672  0.00362724]
# Accion 8850
# Observación [-0.34458166 -0.0128302 ]
# Accion 8860
# Observación [-0.52832115 -0.02142236]
# Accion 8870
# Observación [-0.7470398  -0.01766982]
# Accion 8880
# Observación [-0.83611196  0.00086886]
# Accion 8890
# Observación [-0.71032614  0.0200416 ]
# Accion 8900
# Observación [-0.4565886   0.02893056]
# Accion 8910
# Observación [-0.23409152  0.01539283]
# Accion 8920
# Observación [-0.18913732 -0.00330625]
# Accion 8930
# Observación [-0.3082426  -0.01849481]
# Accion 8940
# Observación [-0.55555606 -0.02750009]
# Accion 8950
# Observación [-0.7632491  -0.01256386]
# Accion 8960
# Observación [-0.78997487  0.00313123]
# Accion 8970
# Observación [-0.6714707   0.01652308]
# Accion 8980
# Observación [-0.46139106  0.0195042 ]
# Accion 8990
# Observación [-0.29915848  0.00921518]
# Accion 9000
# Observación [-0.3122269  -0.00997362]
# Accion 9010
# Observación [-0.5030067  -0.02489681]
# Accion 9020
# Observación [-0.7432508  -0.01789165]
# Accion 9030
# Observación [-0.82592857 -0.00186202]
# Accion 9040
# Observación [-0.7177744   0.01923324]
# Accion 9050
# Observación [-0.47772676  0.02571959]
# Accion 9060
# Observación [-0.2645211   0.01698015]
# Accion 9070
# Observación [-0.21929488 -0.00544847]
# Accion 9080
# Observación [-0.39130598 -0.02494325]
# Accion 9090
# Observación [-0.6426921 -0.0233122]
# Accion 9100
# Observación [-0.7987299  -0.00923035]
# Accion 9110
# Observación [-0.79295176  0.00972826]
# Accion 9120
# Observación [-0.59534526  0.02626351]
# Accion 9130
# Observación [-0.35750416  0.01803384]
# Accion 9140
# Observación [-0.23056544  0.00606065]
# Accion 9150
# Observación [-0.29082876 -0.0146156 ]
# Accion 9160
# Observación [-0.5012114  -0.02510563]
# Accion 9170
# Observación [-0.7288148  -0.01868276]
# Accion 9180
# Observación [-0.8198203   0.00103268]
# Accion 9190
# Observación [-0.71273863  0.01874022]
# Accion 9200
# Observación [-0.4654027   0.02475477]
# Accion 9210
# Observación [-0.28632304  0.01205251]
# Accion 9220
# Observación [-0.27061254 -0.00860322]
# Accion 9230
# Observación [-0.47038102 -0.02602013]
# Accion 9240
# Observación [-0.741733   -0.02266048]
# Accion 9250
# Observación [-0.84379506 -0.00108063]
# Accion 9260
# Observación [-0.773068   0.0145743]
# Accion 9270
# Observación [-0.5475035   0.02678806]
# Accion 9280
# Observación [-0.31314373  0.01727003]
# Accion 9290
# Observación [-0.21566078  0.00347583]
# Accion 9300
# Observación [-0.28546938 -0.01258712]
# Accion 9310
# Observación [-0.4672434  -0.02124362]
# Accion 9320
# Observación [-0.6904131  -0.01995583]
# Accion 9330
# Observación [-0.7848286  -0.00247532]
# Accion 9340
# Observación [-0.73588586  0.00835948]
# Accion 9350
# Observación [-0.575329   0.0221602]
# Accion 9360
# Observación [-0.35454237  0.01962751]
# Accion 9370
# Observación [-0.25815976  0.00198456]
# Accion 9380
# Observación [-0.34458396 -0.01750842]
# Accion 9390
# Observación [-0.55467385 -0.02196347]
# Accion 9400
# Observación [-0.73874277 -0.01414329]
# Accion 9410
# Observación [-0.78713447  0.00288699]
# Accion 9420
# Observación [-0.6669678   0.02032971]
# Accion 9430
# Observación [-0.42176723  0.026046  ]
# Accion 9440
# Observación [-0.23879236  0.01237568]
# Accion 9450
# Observación [-0.23827139 -0.0061557 ]
# Accion 9460
# Observación [-0.38063395 -0.01900725]
# Accion 9470
# Observación [-0.61003846 -0.02435914]
# Accion 9480
# Observación [-0.7931999  -0.01169121]
# Accion 9490
# Observación [-0.7774083   0.00992316]
# Accion 9500
# Observación [-0.6206738   0.02050748]
# Accion 9510
# Observación [-0.4288965   0.01821858]
# Accion 9520
# Observación [-0.27076998  0.01205622]
# Accion 9530
# Observación [-0.22409247 -0.00288104]
# Accion 9540
# Observación [-0.33509994 -0.01643734]
# Accion 9550
# Observación [-0.5488404  -0.02247503]
# Accion 9560
# Observación [-0.75145334 -0.01451589]
# Accion 9570
# Observación [-0.8133105   0.00256082]
# Accion 9580
# Observación [-0.6888845  0.0193602]
# Accion 9590
# Observación [-0.43842945  0.02649506]
# Accion 9600
# Observación [-0.2304287   0.01537422]
# Accion 9610
# Observación [-0.1861708  -0.00561796]
# Accion 9620
# Observación [-0.321412   -0.02051126]
# Accion 9630
# Observación [-0.58788973 -0.0279888 ]
# Accion 9640
# Observación [-0.79244655 -0.01301532]
# Accion 9650
# Observación [-0.82297313  0.00651178]
# Accion 9660
# Observación [-0.65428907  0.02367637]
# Accion 9670
# Observación [-0.39549935  0.02579587]
# Accion 9680
# Observación [-0.20890656  0.00935377]
# Accion 9690
# Observación [-0.21644478 -0.00838335]
# Accion 9700
# Observación [-0.38751346 -0.02386079]
# Accion 9710
# Observación [-0.62781054 -0.02385941]
# Accion 9720
# Observación [-0.80452365 -0.00910431]
# Accion 9730
# Observación [-0.7957868   0.01014387]
# Accion 9740
# Observación [-0.6113012   0.02410418]
# Accion 9750
# Observación [-0.35281202  0.02503265]
# Accion 9760
# Observación [-0.18178716  0.01072073]
# Accion 9770
# Observación [-0.17763375 -0.01037785]
# Accion 9780
# Observación [-0.39197952 -0.02993634]
# Accion 9790
# Observación [-0.71674275 -0.02976139]
# Accion 9800
# Observación [-0.9354873 -0.0132042]
# Accion 9810
# Observación [-0.9356309   0.00981186]
# Accion 9820
# Observación [-0.71799     0.03041403]
# Accion 9830
# Observación [-0.3884709  0.0327698]
# Accion 9840
# Observación [-0.1589387   0.01487054]
# Accion 9850
# Observación [-0.14054185 -0.00822291]
# Accion 9860
# Observación [-0.3290741  -0.02614023]
# Accion 9870
# Observación [-0.6009022  -0.02747763]
# Accion 9880
# Observación [-0.8184048 -0.0143504]
# Accion 9890
# Observación [-0.8265767   0.00902739]
# Accion 9900
# Observación [-0.6362916   0.02690895]
# Accion 9910
# Observación [-0.35277814  0.02683458]
# Accion 9920
# Observación [-0.15739097  0.01189292]
# Accion 9930
# Observación [-0.16707614 -0.00976163]
# Accion 9940
# Observación [-0.3761231  -0.02791839]
# Accion 9950
# Observación [-0.7022819  -0.03329476]
# Accion 9960
# Observación [-0.9334532  -0.01417097]
# Accion 9970
# Observación [-0.94799656  0.00894689]
# Accion 9980
# Observación [-0.7442295   0.02722315]
# Accion 9990
# Observación [-0.43356803  0.0302062 ]
# Intento 2
# Accion 0
# Observación (array([-0.42093712,  0.        ], dtype=float32), {})
# Accion 10
# Observación [-0.46728927 -0.00644897]
# Accion 20
# Observación [-0.53434   -0.0063475]
# Accion 30
# Observación [-0.5886298 -0.0024861]
# Accion 40
# Observación [-0.5827183   0.00251127]
# Accion 50
# Observación [-0.55519783  0.00292337]
# Accion 60
# Observación [-0.5279455   0.00140633]
# Accion 70
# Observación [-0.5098033   0.00202651]
# Accion 80
# Observación [-0.488719    0.00110299]
# Accion 90
# Observación [-0.47215027  0.00210479]
# Accion 100
# Observación [-0.4590478   0.00075941]
# Accion 110
# Observación [-0.47194454 -0.00293266]
# Accion 120
# Observación [-0.5046925  -0.00150255]
# Accion 130
# Observación [-0.51580715 -0.00269691]
# Accion 140
# Observación [-0.55375236 -0.00407445]
# Accion 150
# Observación [-0.59417254 -0.00343513]
# Accion 160
# Observación [-0.62638074 -0.00101363]
# Accion 170
# Observación [-0.60631025  0.00429017]
# Accion 180
# Observación [-0.50274473  0.01142915]
# Accion 190
# Observación [-0.3986205   0.00822851]
# Accion 200
# Observación [-0.3832173  -0.00516888]
# Accion 210
# Observación [-0.4810031  -0.01151785]
# Accion 220
# Observación [-0.60334706 -0.01153286]
# Accion 230
# Observación [-0.6868353 -0.0024167]
# Accion 240
# Observación [-0.62407714  0.01327076]
# Accion 250
# Observación [-0.44709325  0.02019178]
# Accion 260
# Observación [-0.2725073  0.0137032]
# Accion 270
# Observación [-0.25825194 -0.0066094 ]
# Accion 280
# Observación [-0.40839553 -0.0201232 ]
# Accion 290
# Observación [-0.63330746 -0.02338685]
# Accion 300
# Observación [-0.7860183  -0.00679997]
# Accion 310
# Observación [-0.73861146  0.01156659]
# Accion 320
# Observación [-0.5472148  0.0236062]
# Accion 330
# Observación [-0.31866407  0.01953132]
# Accion 340
# Observación [-0.24029994 -0.00193054]
# Accion 350
# Observación [-0.36392453 -0.01843926]
# Accion 360
# Observación [-0.5724708  -0.02246805]
# Accion 370
# Observación [-0.75552946 -0.01342933]
# Accion 380
# Observación [-0.78513354  0.00408808]
# Accion 390
# Observación [-0.6723749   0.01849883]
# Accion 400
# Observación [-0.42446008  0.02555091]
# Accion 410
# Observación [-0.2550906   0.01140013]
# Accion 420
# Observación [-0.2501949  -0.00965007]
# Accion 430
# Observación [-0.45962736 -0.02818131]
# Accion 440
# Observación [-0.7569792  -0.02377806]
# Accion 450
# Observación [-0.88316184 -0.0029805 ]
# Accion 460
# Observación [-0.8140514   0.01546851]
# Accion 470
# Observación [-0.57229644  0.03091762]
# Accion 480
# Observación [-0.26361218  0.02603598]
# Accion 490
# Observación [-0.09796479  0.0065341 ]
# Accion 500
# Observación [-0.14841738 -0.01528908]
# Accion 510
# Observación [-0.41851696 -0.03390162]
# Accion 520
# Observación [-0.7364974  -0.02874201]
# Accion 530
# Observación [-0.9462694  -0.01265023]
# Accion 540
# Observación [-0.9495      0.00962444]
# Accion 550
# Observación [-0.7151981  0.0304172]
# Accion 560
# Observación [-0.35758618  0.03492762]
# Accion 570
# Observación [-0.11811215  0.01422807]
# Accion 580
# Observación [-0.12682886 -0.01059519]
# Accion 590
# Observación [-0.34071767 -0.03069184]
# Accion 600
# Observación [-0.66826296 -0.03017098]
# Accion 610
# Observación [-0.8843436  -0.01210607]
# Accion 620
# Observación [-0.8992591   0.00977872]
# Accion 630
# Observación [-0.7017783   0.02609293]
# Accion 640
# Observación [-0.3944932   0.03014323]
# Accion 650
# Observación [-0.18162005  0.01296892]
# Accion 660
# Observación [-0.18033376 -0.01118282]
# Accion 670
# Observación [-0.37633243 -0.0280264 ]
# Accion 680
# Observación [-0.6675787  -0.02714485]
# Accion 690
# Observación [-0.858792   -0.01066576]
# Accion 700
# Observación [-0.86560684  0.01023372]
# Accion 710
# Observación [-0.65444297  0.02864962]
# Accion 720
# Observación [-0.35056928  0.0280503 ]
# Accion 730
# Observación [-0.16269082  0.01105019]
# Accion 740
# Observación [-0.17400703 -0.01044368]
# Accion 750
# Observación [-0.37952518 -0.02615436]
# Accion 760
# Observación [-0.664988   -0.02730407]
# Accion 770
# Observación [-0.88143164 -0.01561999]
# Accion 780
# Observación [-0.91114247  0.00738806]
# Accion 790
# Observación [-0.70216876  0.02810044]
# Accion 800
# Observación [-0.37817895  0.0315308 ]
# Accion 810
# Observación [-0.13623169  0.01585226]
# Accion 820
# Observación [-0.10870888 -0.00892942]
# Accion 830
# Observación [-0.32396534 -0.03065138]
# Accion 840
# Observación [-0.66254514 -0.03099844]
# Accion 850
# Observación [-0.8790269  -0.01315063]
# Accion 860
# Observación [-0.8662145   0.01225947]
# Accion 870
# Observación [-0.64931494  0.02954738]
# Accion 880
# Observación [-0.3556933   0.02581556]
# Accion 890
# Observación [-0.1607575   0.01216473]
# Accion 900
# Observación [-0.15709168 -0.00962563]
# Accion 910
# Observación [-0.3718208  -0.03138512]
# Accion 920
# Observación [-0.7246297  -0.03169615]
# Accion 930
# Observación [-0.949734   -0.01060224]
# Accion 940
# Observación [-0.95039636  0.00867553]
# Accion 950
# Observación [-0.7694814   0.02549528]
# Accion 960
# Observación [-0.46286663  0.0347479 ]
# Accion 970
# Observación [-0.15762593  0.02259306]
# Accion 980
# Observación [-0.05103359  0.00069264]
# Accion 990
# Observación [-0.16451608 -0.02043099]
# Accion 1000
# Observación [-0.44671047 -0.03465322]
# Accion 1010
# Observación [-0.7698523 -0.0250101]
# Accion 1020
# Observación [-0.9257548  -0.00510176]
# Accion 1030
# Observación [-0.86938155  0.01504074]
# Accion 1040
# Observación [-0.6052635   0.03418542]
# Accion 1050
# Observación [-0.27851632  0.02913796]
# Accion 1060
# Observación [-0.10856915  0.00815349]
# Accion 1070
# Observación [-0.16255255 -0.01641112]
# Accion 1080
# Observación [-0.45348644 -0.03572018]
# Accion 1090
# Observación [-0.7836812  -0.02978892]
# Accion 1100
# Observación [-0.9858775  -0.00982089]
# Accion 1110
# Observación [-0.95437634  0.01381023]
# Accion 1120
# Observación [-0.7237483   0.02975443]
# Accion 1130
# Observación [-0.39255425  0.03030402]
# Accion 1140
# Observación [-0.18713835  0.0121684 ]
# Accion 1150
# Observación [-0.1983076  -0.01364133]
# Accion 1160
# Observación [-0.45213836 -0.0319786 ]
# Accion 1170
# Observación [-0.7726531  -0.02962394]
# Accion 1180
# Observación [-0.91998225 -0.00466475]
# Accion 1190
# Observación [-0.8440232   0.01702617]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 19
#      16 action = env.action_space.sample()
#      17 # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
#      18 # que nos indica que ha alcanzado su objetivo e info debug
# ---> 19 observation, reward, done, truncated, info = env.step(action)
#      20 if done:
#      21     print("Episode finished after {} timesteps".format(t+1))
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)    123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/envs/classic_control/mountain_car.py:152, in MountainCarEnv.step(self, action)
#     150 self.state = (position, velocity)
#     151 if self.render_mode == "human":
# --> 152     self.render()
#     153 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     154 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/gymnasium/envs/classic_control/mountain_car.py:271, in MountainCarEnv.render(self)
#     269 if self.render_mode == "human":
#     270     pygame.event.pump()
# --> 271     self.clock.tick(self.metadata["render_fps"])
#     272     pygame.display.flip()
#     274 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
gym.__version__
# Out:
# '1.2.3'
