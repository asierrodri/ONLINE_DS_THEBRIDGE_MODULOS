# %% [markdown]
# ## Mini Hundir la Flota
# #### Primeros pasos
# Vamos a empezar a programar trozos de código que nos servirán para el HLF:
#
# * Crear un Tablero como una lista de listas de 10x10 que contenga caracteres espacio: " "
# * Insertar dos barcos sustituyendo en el Tablero los espacios en blanco por el caracter "B":
#     * Uno de 4 casillas en horizontal: casillas [1][0], [1][1], [1][2], [1][3]
#     * Uno de 3 casillas en vertical:   casillas [3][3], [4][3], [4][4], [4][5]
# * Escribir una celda de código separada de las anteriores para simular que el usuario está efectuando un disparo:
#     *  Solicite al usuario dos coordenadas `i,j` mediante dos inputs
#     *  Compruebe si esas coordenadas están ocupada por una casilla barco (que haya una en "B")
#         * Si hay una "B":
#             * Cambiar el contenido de esa posición por una "x"
#             * Imprimir por pantalla el texto "Tocado en posición `i,j`"
#         * Si hay un " ":
#             * Cambiar el contenido de esa posición por una "o"
#             * Imprimir por pantalla el texto "Agua"
#     * Imprimir por pantalla el Tablero
# * Para comprobar que funciona bien la celda de disparar ejecutarla varias veces metiendo distintas coordenadas
#
# ### Bonus
# * En la celda de disparar, si el usuario acierta a tocar un barco, vuelve a disparar
# * Resuélvelo con funciones:
#     * Una para solicitar una coordenada válida a la que llamarás dos veces, una par i y otra par j
#     * Una `disparar` que devuelva `True` si el usuario ha acertado o `False` si no.

# %%
tablero = [[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "],[" ", " ", " ", " ", " ", " ", " ", " ", " ", " "]]
""" 

for p in tablero:
    for i in p:
        print(i, end=" ")
    print() """
x = 0
while x < 4:
    tablero[1][x] = "B"
    x += 1
x = 3
while x < 6:
    tablero[x][3] = "B"
    x += 1
for p in tablero:
    print(p)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
def coordenadas():
    coordenada_correcta = False
    while coordenada_correcta == False:
        coordenada = int(input("Introduce la coordenada"))
        if coordenada > 9 or coordenada < 0:
            print("Coordenadas incorrectas")
        else:
            coordenada_correcta = True
    return coordenada

def disparar(i, j):
    if tablero[i][j] == "B":
        return True
    else:
        return False
    
def pintar_tablero():
    for p in tablero:
        print(p)

def comprobar_coordenadas(i, j):
    if tablero[i][j] == "x" or tablero[i][j] == "o":
        return True
    else:
        return False

# %%
while True:
    pintar_tablero()
    i = coordenadas()
    j = coordenadas()

    if disparar(i, j) == True:
        tablero[i][j] = "x"
        print("Tocado en posición " + str(i) + "," + str(j))
        print("Vuelves a disparar")
        #Si después de acertar introduce unas coordenadas ya introducidas, se sale

    elif comprobar_coordenadas(i,j) == True:
        print("Ya habías introducido esas coordenadas")

    elif tablero[i][j] == " ":
        tablero[i][j] = "o"
        print("Agua")
        pintar_tablero()
        break

    else:
        print("Error desconocido")
        break
""" def disparar():

    i = int(input("Introduce la primera coordenada"))
    j = int(input("Introduce la segunda coordenada"))
    
    if i > 9 or i < 0 or j > 9 or j < 0:
        print("Coordenadas incorrectas")
        disparar()
    elif tablero[i][j] == "B":
        tablero[i][j] = "x"
        print("Tocado en posición " + str(i) + "," + str(j))
        print("Vuelves a disparar")
        for p in tablero:
            print(p)
        disparar()
    elif tablero[i][j] == " ":
        tablero[i][j] = "o"
        print("Agua")
        for p in tablero:
            print(p)
    else:
        print("Ya habías introducido esas coordenadas")
        disparar()

disparar() """
# Out:
# ['o', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['x', 'B', 'x', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Tocado en posición 1,1
# Vuelves a disparar
# ['o', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['x', 'x', 'x', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Ya habías introducido esas coordenadas
# ['o', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['x', 'x', 'x', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Ya habías introducido esas coordenadas
# ['o', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['x', 'x', 'x', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# Agua
# ['o', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['x', 'x', 'x', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', 'o', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', 'o', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ' def disparar():\n\n    i = int(input("Introduce la primera coordenada"))\n    j = int(input("Introduce la segunda coordenada"))\n\n    if i > 9 or i < 0 or j > 9 or j < 0:\n        print("Coordenadas incorrectas")\n        disparar()\n    elif tablero[i][j] == "B":\n        tablero[i][j] = "x"\n        print("Tocado en posición " + str(i) + "," + str(j))\n        print("Vuelves a disparar")\n        for p in tablero:\n            print(p)\n        disparar()\n    elif tablero[i][j] == " ":\n        tablero[i][j] = "o"\n        print("Agua")\n        for p in tablero:\n            print(p)\n    else:\n        print("Ya habías introducido esas coordenadas")\n        disparar()\n\ndisparar() '
