# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]

ejer_1.reverse() #Modifica la original
print(ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Otra forma

# %%
ejer_1 = [1,2,3,4,5]
print(ejer_1[::-1]) #slicing
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Otra forma

# %%
print(list(reversed(ejer_1))) #función
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]

for i in ejer_2:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ```['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']```

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

for i in ejer_3_1:
    for x in ejer_3_2:
        print(i + " " + x)
# Out:
# Hola Que
# Hola tal
# amigo Que
# amigo tal

# %%
import itertools

ejer_3_results = []

for combination in itertools.product(ejer_3_1, ejer_3_2):
    string = ""
    for value in combination:
        string = string + " " + value
    ejer_3_results.append(string[1:])

print(ejer_3_results)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra por el índice el valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20,47,19,29,45,67,78,90]

indice = ejer_4.index(45)
ejer_4[indice] = 0

print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# TIP: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
copia = ejer_5.copy()
i = 0

while i < len(ejer_5):
    if ejer_5[i] == 3:
        copia.remove(3)
    i += 1

print(ejer_5)
print(copia)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y último elemento de la tupla del apartado 3. Usa `len` para el último
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
tupla1 = (6,1,45)
tupla2 = (34,)

print(type(tupla2))

tupla3 = (False, 12, "persona")

print(tupla3[0:len(tupla3):2])

tupla4 = tupla3 + (45,)
print(tupla4)

tupla5 = tupla4[:2] + tupla4[3:] 
print(tupla5)

tupla6 = list(tupla4)
print(tupla6)
# Out:
# <class 'tuple'>
# (False, 'persona')
# (False, 12, 'persona', 45)
# (False, 12, 45)
# [False, 12, 'persona', 45]

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un único string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")

print(" ".join(ejer_7))
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)

print(ejer_8[2])
print(ejer_8[len(ejer_8) - 3])
print(ejer_8[- 3])
# Out:
# 3
# 90
# 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posición 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# 4. Comprueba si el numero 60 está en la tupla
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

i = 0

for numero in ejer_9:
    if numero == 3:
        i += 1

print(i)
# Out:
# 7

# %%
posiciones = ejer_9[5:11]
print(posiciones)
# Out:
# (3, 29, 45, 67, 78, 90)

# %%
print(len(ejer_9))
# Out:
# 26

# %%
sesenta = False

for numero in ejer_9:
    if numero == 60:
        sesenta = True

print(sesenta)
# Out:
# False

# %% [markdown]
# ## Ejercicio 10
# 1. Convierte la tupla del ejercicio 9 en una lista
# 2. Convierte la tupla del ejercicio 9 en un set
# 3. Convierte la tupla del ejercicio 9 en un diccionario. Usa también los índices

# %%
print(list(ejer_9))
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]

# %%
print(type(set(ejer_9)))
# Out:
# <class 'set'>

# %%
diccionario = {}
for indice, valor in enumerate(ejer_9):
    diccionario[indice] = valor

print(diccionario)
# Out:
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %%
dict(enumerate(ejer_9))
# Out:
# {0: 3,
#  1: 20,
#  2: 3,
#  3: 47,
#  4: 19,
#  5: 3,
#  6: 29,
#  7: 45,
#  8: 67,
#  9: 78,
#  10: 90,
#  11: 3,
#  12: 3,
#  13: 5,
#  14: 2,
#  15: 4,
#  16: 7,
#  17: 9,
#  18: 4,
#  19: 2,
#  20: 4,
#  21: 3,
#  22: 3,
#  23: 4,
#  24: 6,
#  25: 7}

# %% [markdown]
# ## Ejercicio 11
# Convierte la siguiente lista en un diccionario
# > ```ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
mi_dict = {}

for clave, valor in ejer_11:
    if clave in mi_dict:
        mi_dict[clave] += valor
    else:
        mi_dict[clave] = valor

print(mi_dict)
# Out:
# {'x': 6, 'y': 3, 'z': 1}

# %%
diccionario = {}

for clave, valor in ejer_11:
    if clave in diccionario.keys():
        diccionario[clave].append(valor)
    else:
        diccionario[clave] = [valor]
print(diccionario)
# Out:
# {'x': [1, 2, 3], 'y': [1, 2], 'z': [1]}

# %% [markdown]
# ## Ejercicio 12
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave igual a 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un único for
# > ```ejer_12 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_12 = {4:78, 2:98, 8:234, 5:29}
lista_ascendente = sorted(ejer_12.keys())
print(lista_ascendente)

lista_descendente = sorted(ejer_12.values())
lista_descendente.reverse()
print(lista_descendente)

ejer_12[1] = 13
print(ejer_12)

if 2 in ejer_12:
    print(ejer_12[2])
else:
    print("Clave 2 no existe")

for i in ejer_12:
    print(i, ejer_12[i])
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# {4: 78, 2: 98, 8: 234, 5: 29, 1: 13}
# 98
# 4 78
# 2 98
# 8 234
# 5 29
# 1 13

# %% [markdown]
# ## Ejercicio 13
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_13_1 = {1: 11, 2: 22}```
# >
# > ```ejer_13_2 = {3: 33, 4: 44}```

# %%
ejer_13_1 = {1: 11, 2: 22, 3:18}
ejer_13_2 = {3: 33, 4: 44}

#ejer_13_1.update(ejer_13_2)

print(ejer_13_1)
# Out:
# {1: 11, 2: 22, 3: 18}

# %%
juntadas = ejer_13_2 | ejer_13_1
print(juntadas)
# Out:
# {3: 18, 4: 44, 1: 11, 2: 22}

# %% [markdown]
# ## Ejercicio 14
# Suma todos los valores del dicionario
# > ```ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
print(sum(ejer_14.values()))
# Out:
# 165

# %% [markdown]
# ## Ejercicio 15
# Multiplica todos los valores del diccionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
resultado = 1

for i in ejer_15.values():
    resultado *= i

print(resultado)
# Out:
# 19326120

# %% [markdown]
# ## Ejercicio 16
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el último elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
mi_set = {"elemento1", "elemento2", "elemento3"}
print(mi_set)
mi_set.add("elemento4")
print(mi_set)
mi_set.remove("elemento4")
print(mi_set)
mi_set.discard(10)
print(mi_set)
# Out:
# {'elemento2', 'elemento1', 'elemento3'}
# {'elemento4', 'elemento2', 'elemento1', 'elemento3'}
# {'elemento2', 'elemento1', 'elemento3'}
# {'elemento2', 'elemento1', 'elemento3'}
